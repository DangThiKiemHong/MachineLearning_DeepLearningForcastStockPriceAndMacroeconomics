# %% [markdown]
# **Học tăng cường XGBoost**

# %% [markdown]
# 1. Tải dữ liệu
# 2. Sử dụng hàm XGBClassifier cho bài toán phân lớp và XGBRegressor cho bài toán hồi quy từ thư viện xgboost

# %% [markdown]
# **VCB**

# %%
import pandas as pd
# Đọc dữ liệu từ file CSV (có thể thay bằng file của bạn)
#df = pd.read_csv('VCB_hose.csv')
file_path = r'D:\DeTaiNam2024\SolieuHong\VCB.csv'
df = pd.read_csv(file_path)
# Kiểm tra tiêu đề các cột
df.head()
# Out:
#    Unnamed: 0        time   open   high    low  close   volume
# 0           0  2015-01-05  14.03  14.21  13.90  14.12   310010
# 1           1  2015-01-06  14.12  15.05  14.12  15.05  1684600
# 2           2  2015-01-07  15.09  15.31  14.65  14.87  1430340
# 3           3  2015-01-08  14.92  15.49  14.87  15.31   904240
# 4           4  2015-01-09  15.45  16.38  15.45  16.33  2286680

# %%
# Sắp xếp theo ngày
df = df.sort_values('time')

# Tạo cột Y: nếu giá đóng cửa hôm nay thấp hơn hôm qua, Y=0, nếu ngược lại Y=1
df['Y'] = (df['close'].diff() > 0).astype(int)

# Hiển thị dữ liệu với cột Y
print(df[['time', 'close', 'Y']])
# Out:
#             time  close  Y
# 0     2015-01-05  14.12  0
# 1     2015-01-06  15.05  1
# 2     2015-01-07  14.87  0
# 3     2015-01-08  15.31  1
# 4     2015-01-09  16.33  1
# ...          ...    ... ..
# 2421  2024-09-13  89.90  1
# 2422  2024-09-16  88.90  0
# 2423  2024-09-17  90.50  1
# 2424  2024-09-18  91.00  1
# 2425  2024-09-19  91.60  1
#
# [2426 rows x 3 columns]

# %%
pip install xgboost
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: xgboost in c:\users\admin\appdata\roaming\python\python39\site-packages (2.1.1)
# Requirement already satisfied: numpy in c:\users\admin\appdata\roaming\python\python39\site-packages (from xgboost) (1.24.4)
# Requirement already satisfied: scipy in c:\programdata\anaconda3\lib\site-packages (from xgboost) (1.9.1)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\admin\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\admin\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\admin\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\admin\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\admin\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\admin\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\admin\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\admin\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\admin\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\admin\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\admin\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\admin\appdata\roaming\python\python39\site-packages)

# %%
from sklearn.model_selection import train_test_split
import time
import xgboost as xgb
from sklearn.metrics import mean_squared_error, r2_score
import matplotlib.pyplot as plt
import numpy as np
# Tạo các đặc trưng (ở đây ta chỉ sử dụng giá hôm trước và khối lượng giao dịch)
df['Close_lag1'] = df['close'].shift(1)
df['Volume_lag1'] = df['volume'].shift(1)

# Loại bỏ các hàng chứa giá trị NaN
df.dropna(inplace=True)

# Chọn các đặc trưng (X) và mục tiêu (Y)
X = df[['Close_lag1', 'Volume_lag1']]
Y = df['close']


# Chia dữ liệu thành tập huấn luyện và tập kiểm tra
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3, random_state=42)
# Bắt đầu tính thời gian huấn luyện
start_time = time.time()
# Tạo mô hình XGBoost cho bài toán phân loại
model = xgb.XGBRegressor(objective='reg:squarederror', n_estimators=1000, learning_rate=0.05)

# Huấn luyện mô hình trên tập huấn luyện
model.fit(X_train, Y_train,  eval_set=[(X_test, Y_test)], verbose=False)
# Kết thúc tính thời gian huấn luyện
train_time_cls = time.time() - start_time
print(f'Thời gian huấn luyện mô hình phân loại: {train_time_cls:.4f} giây')

# Bắt đầu tính thời gian dự đoán
start_time = time.time()

# Dự đoán trên tập kiểm tra
Y_pred = model.predict(X_test)
# Kết thúc tính thời gian huấn luyện
train_time_cls = time.time() - start_time
print(f'Thời gian huấn luyện mô hình phân loại: {train_time_cls:.4f} giây')

# Bắt đầu tính thời gian dự đoán
start_time = time.time()
#Đánh giá mô hình
mse = mean_squared_error(Y_test, Y_pred)
r2 = r2_score(Y_test, Y_pred)
print(f"Mean Squared Error: {mse}")
print(f"R^2: {r2}")

mse1=np.mean(np.square(Y_pred - Y_test))
print('MSE=', mse1)
mean_error_percent1 = np.mean(np.abs((Y_pred - Y_test) / Y_test))
accuracy1 = 1 - mean_error_percent1
print('Accuracy=', accuracy1)
print('mean_error_percent=', mean_error_percent1)
# Out:
# Thời gian huấn luyện mô hình phân loại: 1.4488 giây
# Thời gian huấn luyện mô hình phân loại: 0.0156 giây
# Mean Squared Error: 1.1915877417811627
# R^2: 0.9979122264277844
# MSE= 1.1915877417811631
# Accuracy= 0.9834773424706841
# mean_error_percent= 0.016522657529315928

# %% [markdown]
# HNX

# %%
import pandas as pd
# Đọc dữ liệu từ file CSV (có thể thay bằng file của bạn)
file_path = r'D:\DeTaiNam2024\SolieuHong\HNX.csv'
df = pd.read_csv(file_path)


# Chọn các đặc trưng (X) và mục tiêu (Y)
X = df[['open',  'high', 'volume']]
Y = df['close']


# Chia dữ liệu thành tập huấn luyện và tập kiểm tra
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3, random_state=42)
# Bắt đầu tính thời gian huấn luyện
start_time = time.time()
# Tạo mô hình XGBoost cho bài toán phân loại
model = xgb.XGBRegressor(objective='reg:squarederror', n_estimators=1000, learning_rate=0.05)

# Huấn luyện mô hình trên tập huấn luyện
model.fit(X_train, Y_train,  eval_set=[(X_test, Y_test)], verbose=False)
# Kết thúc tính thời gian huấn luyện
train_time_cls = time.time() - start_time
print(f'Thời gian huấn luyện mô hình phân loại: {train_time_cls:.4f} giây')

# Bắt đầu tính thời gian dự đoán
start_time = time.time()

# Dự đoán trên tập kiểm tra
Y_pred = model.predict(X_test)
# Kết thúc tính thời gian huấn luyện
train_time_cls = time.time() - start_time
print(f'Thời gian huấn luyện mô hình phân loại: {train_time_cls:.4f} giây')

# Bắt đầu tính thời gian dự đoán
start_time = time.time()
#Đánh giá mô hình
mse = mean_squared_error(Y_test, Y_pred)
r2 = r2_score(Y_test, Y_pred)
print(f"Mean Squared Error: {mse}")
print(f"R^2: {r2}")
# Out:
# Thời gian huấn luyện mô hình phân loại: 3.0877 giây
# Thời gian huấn luyện mô hình phân loại: 0.0320 giây
# Mean Squared Error: 74.00073005911642
# R^2: 0.99763143535949

# %%
VCB LÂU ĐỜI

# %%
import pandas as pd
# Đọc dữ liệu từ file CSV (có thể thay bằng file của bạn)
file_path = r'D:\DeTaiNam2024\Solieu\CK_laudoi\excel_vcb.csv'
df = pd.read_csv(file_path)
# Kiểm tra tiêu đề các cột
df.head()
# Out:
#    time <Ticker>  <DTYYYYMMDD>   <Open>   <High>    <Low>  <Close>  <Volume>
# 0     0      VCB      20090630  16.2426  16.2426  16.2426  16.2426    294070
# 1     1      VCB      20090701  16.2426  17.0547  16.1072  16.3779   6248390
# 2     2      VCB      20090702  16.3779  16.3779  15.5658  15.7011   1515670
# 3     3      VCB      20090703  15.7011  15.7011  15.1597  15.1597    899720
# 4     4      VCB      20090706  15.1597  15.8365  15.1597  15.8365   1571740

# %%
# Tạo các đặc trưng (ở đây ta chỉ sử dụng giá hôm trước và khối lượng giao dịch)
df['open']=df['<Open>']
df['high']=df['<High>']
df['volume']=df['<Volume>']
# Loại bỏ các hàng chứa giá trị NaN
df.dropna(inplace=True)

# Chọn các đặc trưng (X) và mục tiêu (Y)
X = df[['open', 'high', 'volume']]
Y = df['<Close>']


# Chia dữ liệu thành tập huấn luyện và tập kiểm tra
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3, random_state=42)
# Bắt đầu tính thời gian huấn luyện
start_time = time.time()
# Tạo mô hình XGBoost cho bài toán phân loại
model = xgb.XGBRegressor(objective='reg:squarederror', n_estimators=1000, learning_rate=0.05)

# Huấn luyện mô hình trên tập huấn luyện
model.fit(X_train, Y_train,  eval_set=[(X_test, Y_test)], verbose=False)
# Kết thúc tính thời gian huấn luyện
train_time_cls = time.time() - start_time
print(f'Thời gian huấn luyện mô hình phân loại: {train_time_cls:.4f} giây')

# Bắt đầu tính thời gian dự đoán
start_time = time.time()

# Dự đoán trên tập kiểm tra
Y_pred = model.predict(X_test)
# Kết thúc tính thời gian huấn luyện
train_time_cls = time.time() - start_time
print(f'Thời gian huấn luyện mô hình phân loại: {train_time_cls:.4f} giây')

# Bắt đầu tính thời gian dự đoán
start_time = time.time()
#Đánh giá mô hình
mse = mean_squared_error(Y_test, Y_pred)
r2 = r2_score(Y_test, Y_pred)
print(f"Mean Squared Error: {mse}")
print(f"R^2: {r2}")
# Out:
# Thời gian huấn luyện mô hình phân loại: 3.4397 giây
# Thời gian huấn luyện mô hình phân loại: 0.0480 giây
# Mean Squared Error: 0.39154783109984803
# R^2: 0.9994199836069602

# %% [markdown]
# **CHẠY TẤT CẢ**

# %%
import os
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import r2_score, mean_squared_error
import pandas as pd
from sklearn.model_selection import train_test_split
import time
import xgboost as xgb
from sklearn.metrics import mean_squared_error, r2_score
import matplotlib.pyplot as plt
import numpy as np

# %%
# Đường dẫn đến thư mục chứa các file CSV
folder_path = r'D:\DeTaiNam2024\SoLieuHong'

# Lấy danh sách tất cả các file CSV trong thư mục
file_list = [f for f in os.listdir(folder_path) if f.endswith('.csv')]
results=[]
# Vòng lặp qua từng file CSV
for file_name in file_list:
    # Đọc dữ liệu từ file CSV
    file_path = os.path.join(folder_path, file_name)
    df = pd.read_csv(file_path)
    # Tạo các đặc trưng (ở đây ta chỉ sử dụng giá hôm trước và khối lượng giao dịch)
    df['Close_lag1'] = df['close'].shift(1)
    df['Volume_lag1'] = df['volume'].shift(1)

    # Loại bỏ các hàng chứa giá trị NaN
    df.dropna(inplace=True)

    # Chọn các đặc trưng (X) và mục tiêu (Y)
    X = df[['Close_lag1', 'Volume_lag1']]
    Y = df['close']
    
    # Chia dữ liệu thành tập huấn luyện và kiểm tra
    X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)
    
    
    # Tạo mô hình XGBoost cho bài toán phân loại
    model = xgb.XGBRegressor(objective='reg:squarederror', n_estimators=1000, learning_rate=0.05)

    # Huấn luyện mô hình trên tập huấn luyện
    model.fit(X_train, Y_train,  eval_set=[(X_test, Y_test)], verbose=False)
    
   

    # Dự đoán trên tập kiểm tra
    Y_pred = model.predict(X_test)
   

    
    #Đánh giá mô hình
    mse = mean_squared_error(Y_test, Y_pred)
    r2 = r2_score(Y_test, Y_pred)
    mse1=np.mean(np.square(Y_pred - Y_test))
    mean_error_percent1 = np.mean(np.abs((Y_pred - Y_test) / Y_test))
    accuracy1 = 1 - mean_error_percent1
    # Lưu kết quả vào danh sách
    results.append({
        'file': file_name,
        'mse': mse,
        'r^2': r2,
        'mse1':mse1,
        'accuracy':accuracy1
    })
# Ghi kết quả ra file CSV
results_df = pd.DataFrame(results)
results_df.to_csv(r'D:\DeTaiNam2024\SoLieuHong\output\XGBoost_Regressor_results_m.csv', index=False)

# %% [markdown]
# **Dự báo cho 7 ngày tiếp theo**

# %%
import pandas as pd
import os
import xgboost as xgb
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score
import numpy as np

# Đường dẫn đến thư mục chứa các file CSV
folder_path = r'D:\DeTaiNam2024\SoLieu\CK_HOSE_VNSTOCK'

# Lấy danh sách tất cả các file CSV trong thư mục
file_list = [f for f in os.listdir(folder_path) if f.endswith('.csv')]
results = []

# Vòng lặp qua từng file CSV
for file_name in file_list:
    # Đọc dữ liệu từ file CSV
    file_path = os.path.join(folder_path, file_name)
    df = pd.read_csv(file_path)
    
    # Chọn các đặc trưng (X) và mục tiêu (Y)
    X = df[['open', 'high', 'volume']]
    Y = df['close']

    # Chia dữ liệu thành tập huấn luyện và kiểm tra
    X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

    # Tạo mô hình XGBoost cho bài toán hồi quy
    model = xgb.XGBRegressor(objective='reg:squarederror', n_estimators=1000, learning_rate=0.05)

    # Huấn luyện mô hình trên tập huấn luyện
    model.fit(X_train, Y_train, eval_set=[(X_test, Y_test)], verbose=False)

    # Dự đoán trên tập kiểm tra
    Y_pred = model.predict(X_test)

    # Đánh giá mô hình
    mse = mean_squared_error(Y_test, Y_pred)
    r2 = r2_score(Y_test, Y_pred)
    
    # Dự đoán giá cho 7 ngày tiếp theo
    last_data = X.iloc[-1:].copy()  # Lấy dữ liệu của ngày cuối cùng để dự đoán
    future_prices = []
    
    for i in range(7):
        # Dự đoán giá cho ngày tiếp theo
        predicted_price = model.predict(last_data)[0]
        future_prices.append(predicted_price)

        # Giả định giá mở cửa, cao, khối lượng dựa trên một số thay đổi ngẫu nhiên cho các ngày tiếp theo
        last_data['open'] = predicted_price * np.random.uniform(0.99, 1.01)  # Giả định giá mở cửa xấp xỉ dự báo
        last_data['high'] = predicted_price * np.random.uniform(1.0, 1.02)  # Giả định giá cao hơn chút
        last_data['volume'] = last_data['volume'] * np.random.uniform(0.95, 1.05)  # Khối lượng giao dịch biến động ngẫu nhiên

    # Lưu kết quả vào danh sách
    results.append({
        'file': file_name,
        'mse': mse,
        'r^2': r2,
        '7_day_forecast': future_prices
    })

# Ghi kết quả ra file CSV
results_df = pd.DataFrame(results)
results_df.to_csv(r'D:\DeTaiNam2024\SoLieu\CK_HOSE_VNSTOCK\output\XGBoost_Regressor_results_HOSE_dubao7ngay.csv', index=False)

# Hiển thị kết quả dự báo cho từng file
for result in results:
    print(f"Kết quả dự báo cho {result['file']}:")
    print(f"  MSE: {result['mse']}")
    print(f"  R^2: {result['r^2']}")
    print(f"  Dự báo giá 7 ngày tiếp theo: {result['7_day_forecast']}")
# Out:
# C:\Users\Admin\AppData\Roaming\Python\Python39\site-packages\sklearn\metrics\_regression.py:996: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\Admin\AppData\Roaming\Python\Python39\site-packages\sklearn\metrics\_regression.py:996: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# Kết quả dự báo cho AAA.csv:
#   MSE: 0.05251590790811251
#   R^2: 0.9966198562562445
#   Dự báo giá 7 ngày tiếp theo: [9.822149, 9.884826, 9.888404, 9.791221, 9.734202, 9.732133, 9.733669]
# Kết quả dự báo cho AAM.csv:
#   MSE: 0.05194271044280398
#   R^2: 0.9904906187756555
#   Dự báo giá 7 ngày tiếp theo: [7.5668135, 7.354431, 7.307224, 7.252327, 7.1188655, 7.131192, 7.067581]
# Kết quả dự báo cho AAT.csv:
#   MSE: 0.03899774750748793
#   R^2: 0.9978175954275214
#   Dự báo giá 7 ngày tiếp theo: [3.6388016, 3.6388016, 3.5605521, 3.5438182, 3.4887433, 3.5367637, 3.4887433]
# Kết quả dự báo cho ABR.csv:
#   MSE: 0.24420326749012403
#   R^2: 0.9953271563681305
#   Dự báo giá 7 ngày tiếp theo: [13.656554, 13.419417, 13.445647, 13.523551, 13.442643, 13.496587, 13.515179]
# Kết quả dự báo cho ABS.csv:
#   MSE: 0.2963182073109187
#   R^2: 0.9970932396906956
#   Dự báo giá 7 ngày tiếp theo: [4.387501, 4.3443494, 4.3541813, 4.34273, 4.3127437, 4.2768025, 4.3114853]
# Kết quả dự báo cho ABT.csv:
#   MSE: 0.3366768004312621
#   R^2: 0.9788157832442157
#   Dự báo giá 7 ngày tiếp theo: [40.53631, 41.200512, 41.200512, 40.53631, 41.200512, 41.334724, 41.022953]
# Kết quả dự báo cho ACB.csv:
#   MSE: 0.0330011891782477
#   R^2: 0.9992161420429279
#   Dự báo giá 7 ngày tiếp theo: [24.776772, 24.751772, 24.812748, 24.721306, 24.825542, 24.61101, 24.527132]
# Kết quả dự báo cho ACC.csv:
#   MSE: 0.04542467303942961
#   R^2: 0.9976118058891011
#   Dự báo giá 7 ngày tiếp theo: [13.742205, 13.51565, 12.956831, 12.888616, 12.888616, 12.917144, 12.920051]
# Kết quả dự báo cho ACG.csv:
#   MSE: 0.6250635069466983
#   R^2: 0.9937712339546719
#   Dự báo giá 7 ngày tiếp theo: [41.939903, 41.767387, 41.75323, 41.086548, 41.190178, 41.14568, 40.501553]
# Kết quả dự báo cho ACL.csv:
#   MSE: 0.11427992841101214
#   R^2: 0.9967776281673444
#   Dự báo giá 7 ngày tiếp theo: [11.911577, 12.008228, 11.948842, 12.079177, 12.159607, 12.228508, 12.414872]
# Kết quả dự báo cho ADG.csv:
#   MSE: 0.5498461168211446
#   R^2: 0.9943962696794311
#   Dự báo giá 7 ngày tiếp theo: [12.389921, 12.68015, 12.926793, 13.111117, 13.111117, 13.313808, 13.354354]
# Kết quả dự báo cho ADP.csv:
#   MSE: 0.30517610143185153
#   R^2: 0.9926069180639494
#   Dự báo giá 7 ngày tiếp theo: [30.162724, 30.754154, 30.216026, 30.450073, 30.754154, 30.216026, 30.24357]
# Kết quả dự báo cho ADS.csv:
#   MSE: 0.04374406725816915
#   R^2: 0.9985068185444854
#   Dự báo giá 7 ngày tiếp theo: [9.984073, 9.985856, 10.178458, 10.1331625, 10.282298, 10.197137, 10.248725]
# Kết quả dự báo cho AGG.csv:
#   MSE: 0.09016074305683452
#   R^2: 0.9967838830620261
#   Dự báo giá 7 ngày tiếp theo: [16.678833, 16.820463, 16.832094, 16.92193, 16.80864, 16.81086, 17.00806]
# Kết quả dự báo cho AGM.csv:
#   MSE: 0.2813898905978353
#   R^2: 0.9977478528847814
#   Dự báo giá 7 ngày tiếp theo: [4.7760153, 4.7760153, 4.7359405, 4.740788, 4.740788, 4.7027516, 4.740788]
# Kết quả dự báo cho AGR.csv:
#   MSE: 0.03751124122797333
#   R^2: 0.9989410767651634
#   Dự báo giá 7 ngày tiếp theo: [18.408003, 18.408003, 18.100828, 17.950518, 18.014265, 17.97108, 17.491096]
# Kết quả dự báo cho ANV.csv:
#   MSE: 0.2754068500393727
#   R^2: 0.9983269211781025
#   Dự báo giá 7 ngày tiếp theo: [31.993359, 32.146137, 32.483414, 32.449566, 32.37441, 31.793161, 31.435074]
# Kết quả dự báo cho APG.csv:
#   MSE: 0.03204264188916566
#   R^2: 0.9980574881980322
#   Dự báo giá 7 ngày tiếp theo: [9.806627, 9.687325, 9.634866, 9.557179, 9.558562, 9.508401, 9.5718775]
# Kết quả dự báo cho APH.csv:
#   MSE: 0.26355345822537096
#   R^2: 0.9989422977130288
#   Dự báo giá 7 ngày tiếp theo: [6.2682276, 6.1708474, 5.856671, 5.85503, 5.9223695, 5.9187694, 5.9135323]
# Kết quả dự báo cho ASG.csv:
#   MSE: 0.11483661752904269
#   R^2: 0.9889216909187712
#   Dự báo giá 7 ngày tiếp theo: [19.256052, 19.316658, 19.444725, 19.743694, 19.993773, 20.092184, 20.292465]
# Kết quả dự báo cho ASM.csv:
#   MSE: 0.05096594519773661
#   R^2: 0.9949867520774817
#   Dự báo giá 7 ngày tiếp theo: [9.110345, 9.0316, 8.977774, 8.923969, 8.983766, 8.982436, 8.982436]
# Kết quả dự báo cho ASP.csv:
#   MSE: 0.02619332351162802
#   R^2: 0.9957679451398171
#   Dự báo giá 7 ngày tiếp theo: [4.193269, 4.20939, 4.2652636, 4.275576, 4.286731, 4.2733793, 4.26433]
# Kết quả dự báo cho AST.csv:
#   MSE: 0.8482424672512117
#   R^2: 0.9831361630132133
#   Dự báo giá 7 ngày tiếp theo: [56.348656, 56.077316, 55.834316, 56.03995, 55.56448, 55.812824, 55.938885]
# Kết quả dự báo cho BAF.csv:
#   MSE: 0.1259866475033968
#   R^2: 0.9907415637412234
#   Dự báo giá 7 ngày tiếp theo: [20.642275, 20.409164, 20.500631, 20.07538, 19.868786, 19.812628, 19.934248]
# Kết quả dự báo cho BBC.csv:
#   MSE: 2.411690478418812
#   R^2: 0.9889691125923967
#   Dự báo giá 7 ngày tiếp theo: [50.43538, 51.178825, 51.316742, 51.70387, 51.80511, 52.713413, 53.68293]
# Kết quả dự báo cho BCE.csv:
#   MSE: 0.032426725591460134
#   R^2: 0.9978954421852678
#   Dự báo giá 7 ngày tiếp theo: [5.7406044, 5.805256, 5.793041, 5.812822, 5.83827, 5.845341, 5.756246]
# Kết quả dự báo cho BCG.csv:
#   MSE: 0.047917047204971475
#   R^2: 0.9977848858013676
#   Dự báo giá 7 ngày tiếp theo: [6.371487, 6.371487, 6.371487, 6.2868304, 6.257799, 6.0313005, 6.0715303]
# Kết quả dự báo cho BCM.csv:
#   MSE: 0.6889452391203684
#   R^2: 0.998767408722365
#   Dự báo giá 7 ngày tiếp theo: [71.69416, 72.12271, 71.76294, 72.51018, 72.31636, 72.632385, 72.07897]
# Kết quả dự báo cho BFC.csv:
#   MSE: 0.1644394973507115
#   R^2: 0.9970704512201501
#   Dự báo giá 7 ngày tiếp theo: [43.831974, 42.04196, 41.467056, 41.65169, 42.111847, 42.111847, 41.65169]
# Kết quả dự báo cho BHN.csv:
#   MSE: 1.8515455379674925
#   R^2: 0.995569503956735
#   Dự báo giá 7 ngày tiếp theo: [37.82389, 37.747143, 37.380123, 37.14034, 36.909767, 36.521904, 36.262695]
# Kết quả dự báo cho BIC.csv:
#   MSE: 0.1453140995116121
#   R^2: 0.9949673004674235
#   Dự báo giá 7 ngày tiếp theo: [30.339367, 30.220497, 30.308718, 30.33667, 30.150211, 29.906404, 29.906404]
# Kết quả dự báo cho BID.csv:
#   MSE: 0.18372534900377066
#   R^2: 0.9986373939399359
#   Dự báo giá 7 ngày tiếp theo: [49.079124, 49.071022, 48.78293, 48.595387, 48.347385, 48.219116, 48.09757]
# Kết quả dự báo cho BKG.csv:
#   MSE: 0.03014060412872787
#   R^2: 0.9960194005942156
#   Dự báo giá 7 ngày tiếp theo: [3.541011, 3.5523272, 3.540044, 3.5713522, 3.6253524, 3.6332612, 3.598162]
# Kết quả dự báo cho BMC.csv:
#   MSE: 0.07660795832407195
#   R^2: 0.9943313424512233
#   Dự báo giá 7 ngày tiếp theo: [20.534449, 20.326723, 19.302366, 18.48109, 17.829159, 17.634464, 16.964262]
# Kết quả dự báo cho BMI.csv:
#   MSE: 0.1328311961905741
#   R^2: 0.9971555870105722
#   Dự báo giá 7 ngày tiếp theo: [22.799543, 22.415546, 21.97802, 21.995518, 22.106123, 22.175306, 22.032125]
# Kết quả dự báo cho BMP.csv:
#   MSE: 0.6696704657151153
#   R^2: 0.9983433579110401
#   Dự báo giá 7 ngày tiếp theo: [121.59946, 121.59946, 121.59946, 121.59946, 121.59946, 121.502304, 121.59946]
# Kết quả dự báo cho BRC.csv:
#   MSE: 0.029617155050232446
#   R^2: 0.9964093107826342
#   Dự báo giá 7 ngày tiếp theo: [12.498055, 12.512719, 12.40133, 12.424002, 12.37964, 12.433443, 12.379265]
# Kết quả dự báo cho BSI.csv:
#   MSE: 0.21566291728235074
#   R^2: 0.9987497146537836
#   Dự báo giá 7 ngày tiếp theo: [48.766064, 48.51777, 48.32289, 48.29618, 48.60717, 48.816425, 48.712185]
# Kết quả dự báo cho BTP.csv:
#   MSE: 0.018734894263844233
#   R^2: 0.9979279772706521
#   Dự báo giá 7 ngày tiếp theo: [12.894668, 12.89128, 12.822921, 12.840328, 12.832432, 12.783156, 12.786955]
# Kết quả dự báo cho BTT.csv:
#   MSE: 0.47064164473977527
#   R^2: 0.9906201560822581
#   Dự báo giá 7 ngày tiếp theo: [38.835793, 39.12471, 39.25641, 39.29268, 39.29535, 39.320427, 39.30465]
# Kết quả dự báo cho BVH.csv:
#   MSE: 0.9456343234496327
#   R^2: 0.9946923981936664
#   Dự báo giá 7 ngày tiếp theo: [42.965034, 43.01191, 43.155613, 43.389187, 43.34131, 43.13788, 42.946686]
# Kết quả dự báo cho BWE.csv:
#   MSE: 0.28796986321552714
#   R^2: 0.9976375203615093
#   Dự báo giá 7 ngày tiếp theo: [47.027866, 46.399796, 46.50476, 46.399796, 46.42491, 46.302948, 46.60161]
# Kết quả dự báo cho C32.csv:
#   MSE: 0.11093768210889832
#   R^2: 0.9946793218405485
#   Dự báo giá 7 ngày tiếp theo: [17.503595, 17.59294, 17.721718, 17.7534, 17.902714, 17.726715, 17.932938]
# Kết quả dự báo cho C47.csv:
#   MSE: 0.04488602031418227
#   R^2: 0.9953879818261308
#   Dự báo giá 7 ngày tiếp theo: [6.1645303, 6.114301, 6.0862317, 6.0707726, 6.0281725, 5.9350004, 5.8968287]
# Kết quả dự báo cho CCI.csv:
#   MSE: 0.1480445210842711
#   R^2: 0.9971876561250734
#   Dự báo giá 7 ngày tiếp theo: [21.014898, 20.9737, 20.856194, 20.829447, 21.006382, 21.180134, 21.290327]
# Kết quả dự báo cho CCL.csv:
#   MSE: 0.022422632995801738
#   R^2: 0.998169023415104
#   Dự báo giá 7 ngày tiếp theo: [9.177279, 8.948606, 8.895928, 8.893745, 8.882559, 8.895928, 8.887808]
# Kết quả dự báo cho CDC.csv:
#   MSE: 0.04927311148261998
#   R^2: 0.9984762722985585
#   Dự báo giá 7 ngày tiếp theo: [17.518456, 17.425402, 17.713497, 17.548698, 17.69663, 17.639471, 17.532791]
# Kết quả dự báo cho CHP.csv:
#   MSE: 0.03087922274150499
#   R^2: 0.9990061665102437
#   Dự báo giá 7 ngày tiếp theo: [32.77587, 32.803802, 33.28434, 32.981747, 33.22013, 32.981747, 33.28434]
# Kết quả dự báo cho CIG.csv:
#   MSE: 0.046275651856846296
#   R^2: 0.9947153173393832
#   Dự báo giá 7 ngày tiếp theo: [5.2900643, 5.3030896, 5.2736597, 5.297245, 5.2721057, 5.2345796, 5.2842197]
# Kết quả dự báo cho CII.csv:
#   MSE: 0.37022874246993126
#   R^2: 0.9885817221765587
#   Dự báo giá 7 ngày tiếp theo: [15.164768, 15.153286, 15.256403, 15.255095, 15.2412405, 15.0541525, 15.06219]
# Kết quả dự báo cho CKG.csv:
#   MSE: 0.22338597188318685
#   R^2: 0.9961232194832622
#   Dự báo giá 7 ngày tiếp theo: [26.39698, 25.982992, 25.423868, 24.908878, 23.469343, 23.272583, 22.87008]
# Kết quả dự báo cho CLC.csv:
#   MSE: 0.13416607553785737
#   R^2: 0.9977634081429677
#   Dự báo giá 7 ngày tiếp theo: [44.893745, 43.72599, 43.253136, 43.818974, 44.131702, 43.830616, 43.73427]
# Kết quả dự báo cho CLL.csv:
#   MSE: 0.1278204576494789
#   R^2: 0.997142729592888
#   Dự báo giá 7 ngày tiếp theo: [38.46539, 39.127945, 39.03662, 39.589756, 39.184868, 39.36172, 39.5057]
# Kết quả dự báo cho CLW.csv:
#   MSE: 0.2882323683478844
#   R^2: 0.9963087150272478
#   Dự báo giá 7 ngày tiếp theo: [45.90409, 45.989487, 45.989487, 45.989487, 46.00689, 45.989487, 45.989487]
# Kết quả dự báo cho CMG.csv:
#   MSE: 0.22859593269151168
#   R^2: 0.9987307749852364
#   Dự báo giá 7 ngày tiếp theo: [52.26246, 52.42062, 52.26246, 52.42062, 52.42062, 52.42062, 52.42062]
# Kết quả dự báo cho CMV.csv:
#   MSE: 0.039460527563882686
#   R^2: 0.9910954289625744
#   Dự báo giá 7 ngày tiếp theo: [9.799838, 9.811676, 9.879575, 9.932969, 9.957085, 9.961633, 10.031911]
# Kết quả dự báo cho CMX.csv:
#   MSE: 0.06138057159611544
#   R^2: 0.9976337256727554
#   Dự báo giá 7 ngày tiếp theo: [8.134414, 8.085575, 8.04184, 8.035898, 8.03645, 8.064294, 8.069263]
# Kết quả dự báo cho CNG.csv:
#   MSE: 0.11471564914034908
#   R^2: 0.996982870131772
#   Dự báo giá 7 ngày tiếp theo: [34.970966, 35.202045, 35.14829, 35.31621, 35.258114, 34.93648, 35.314125]
# Kết quả dự báo cho COM.csv:
#   MSE: 0.9758519644313782
#   R^2: 0.9851969948486176
#   Dự báo giá 7 ngày tiếp theo: [26.815853, 27.018538, 26.872965, 26.88958, 26.868967, 27.018538, 26.872965]
# Kết quả dự báo cho CRC.csv:
#   MSE: 0.05089190646894141
#   R^2: 0.996247733997401
#   Dự báo giá 7 ngày tiếp theo: [6.5664086, 6.5902395, 6.5918646, 6.573991, 6.563537, 6.5885315, 6.5821047]
# Kết quả dự báo cho CRE.csv:
#   MSE: 0.05582253714711801
#   R^2: 0.9975150947617076
#   Dự báo giá 7 ngày tiếp theo: [7.004389, 6.986383, 6.7502384, 6.6975803, 6.6975803, 6.7136493, 6.775611]
# Kết quả dự báo cho CSM.csv:
#   MSE: 0.04545033197143176
#   R^2: 0.9877321304547096
#   Dự báo giá 7 ngày tiếp theo: [12.587621, 12.58646, 12.669513, 12.690342, 12.733037, 12.795991, 12.778879]
# Kết quả dự báo cho CSV.csv:
#   MSE: 0.08232007542859798
#   R^2: 0.997795170600218
#   Dự báo giá 7 ngày tiếp theo: [38.95075, 38.865845, 38.865845, 38.976814, 38.561222, 37.538944, 36.096]
# Kết quả dự báo cho CTD.csv:
#   MSE: 1.29112422197156
#   R^2: 0.9988497058763532
#   Dự báo giá 7 ngày tiếp theo: [61.323112, 61.535553, 61.38895, 61.299988, 61.588593, 61.29216, 60.348713]
# Kết quả dự báo cho CTF.csv:
#   MSE: 0.08053633111017003
#   R^2: 0.9987421528720595
#   Dự báo giá 7 ngày tiếp theo: [30.138002, 29.997368, 30.4862, 30.483847, 30.867899, 31.153328, 31.242693]
# Kết quả dự báo cho CTG.csv:
#   MSE: 0.09625403728546739
#   R^2: 0.9983766406479132
#   Dự báo giá 7 ngày tiếp theo: [36.015697, 36.193535, 36.14979, 36.252495, 36.04796, 36.16006, 36.51401]
# Kết quả dự báo cho CTI.csv:
#   MSE: 0.093381308380212
#   R^2: 0.9959776826319546
#   Dự báo giá 7 ngày tiếp theo: [15.414464, 15.335323, 15.31696, 15.3406, 15.20564, 15.356895, 15.358453]
# Kết quả dự báo cho CTR.csv:
#   MSE: 1.9936758102338699
#   R^2: 0.9986627535031624
#   Dự báo giá 7 ngày tiếp theo: [134.4708, 132.92676, 131.37883, 131.80338, 131.55223, 131.05353, 126.472084]
# Kết quả dự báo cho CTS.csv:
#   MSE: 0.13996688367746116
#   R^2: 0.998538520745949
#   Dự báo giá 7 ngày tiếp theo: [39.703873, 39.59537, 39.17692, 39.524082, 39.309364, 39.003372, 38.655025]
# Kết quả dự báo cho DBD.csv:
#   MSE: 0.13812868829506603
#   R^2: 0.9978346834482088
#   Dự báo giá 7 ngày tiếp theo: [41.630344, 41.199814, 41.448177, 41.3724, 41.66143, 41.874954, 42.059826]
# Kết quả dự báo cho DBT.csv:
#   MSE: 0.024760361918766502
#   R^2: 0.9910359464572143
#   Dự báo giá 7 ngày tiếp theo: [12.998199, 12.930189, 12.784021, 12.901926, 12.900315, 12.935395, 12.994839]
# Kết quả dự báo cho DC4.csv:
#   MSE: 0.0570098811150752
#   R^2: 0.9967130180560523
#   Dự báo giá 7 ngày tiếp theo: [11.046967, 10.90519, 10.635556, 10.65263, 10.443573, 10.32284, 10.312527]
# Kết quả dự báo cho DCL.csv:
#   MSE: 0.19144049473496993
#   R^2: 0.9973188005995826
#   Dự báo giá 7 ngày tiếp theo: [27.507044, 27.840233, 27.2925, 26.530785, 26.129883, 25.976526, 25.957184]
# Kết quả dự báo cho DCM.csv:
#   MSE: 0.15033540715079702
#   R^2: 0.9986326619924852
#   Dự báo giá 7 ngày tiếp theo: [37.695553, 37.816486, 37.859135, 37.678665, 37.916306, 37.55906, 37.551617]
# Kết quả dự báo cho DGC.csv:
#   MSE: 1.1687873543227454
#   R^2: 0.9990631064044412
#   Dự báo giá 7 ngày tiếp theo: [114.53074, 115.338455, 115.338455, 115.338455, 116.51127, 116.51127, 117.886314]
# Kết quả dự báo cho DGW.csv:
#   MSE: 0.37937821100279645
#   R^2: 0.998881476555773
#   Dự báo giá 7 ngày tiếp theo: [47.37146, 46.458965, 46.063576, 44.845932, 44.572895, 44.040073, 43.641758]
# Kết quả dự báo cho DHA.csv:
#   MSE: 0.17745482533100293
#   R^2: 0.9987552888157502
#   Dự báo giá 7 ngày tiếp theo: [40.286964, 40.077515, 40.068398, 40.049202, 39.96226, 40.180573, 40.366592]
# Kết quả dự báo cho DHC.csv:
#   MSE: 0.2238976237114789
#   R^2: 0.9993106506585292
#   Dự báo giá 7 ngày tiếp theo: [37.583405, 37.56306, 37.60616, 38.00946, 38.230686, 38.244938, 38.113796]
# Kết quả dự báo cho DHG.csv:
#   MSE: 1.1369250433432043
#   R^2: 0.9978696103758801
#   Dự báo giá 7 ngày tiếp theo: [107.529175, 107.604706, 108.64661, 109.02401, 109.11059, 109.25707, 109.30555]
# Kết quả dự báo cho DHM.csv:
#   MSE: 0.023920267056630275
#   R^2: 0.9980271807586979
#   Dự báo giá 7 ngày tiếp theo: [8.705884, 8.599581, 8.525023, 8.50156, 8.50156, 8.472835, 8.45506]
# Kết quả dự báo cho DIG.csv:
#   MSE: 0.822089297347987
#   R^2: 0.9970969450387432
#   Dự báo giá 7 ngày tiếp theo: [22.663042, 22.1192, 21.848705, 21.848705, 21.72725, 21.458895, 21.426958]
# Kết quả dự báo cho DLG.csv:
#   MSE: 0.010835287270592006
#   R^2: 0.9977433489490942
#   Dự báo giá 7 ngày tiếp theo: [1.7010857, 1.6554627, 1.61155, 1.5946518, 1.5674158, 1.5674158, 1.5325893]
# Kết quả dự báo cho DMC.csv:
#   MSE: 0.7088560102160898
#   R^2: 0.9976152818845073
#   Dự báo giá 7 ngày tiếp theo: [65.73218, 65.281586, 64.84577, 64.66764, 64.89979, 64.67393, 64.39504]
# Kết quả dự báo cho DPG.csv:
#   MSE: 0.7399557340920632
#   R^2: 0.9974280037812592
#   Dự báo giá 7 ngày tiếp theo: [56.504604, 55.805634, 54.76226, 54.9195, 53.53385, 53.406673, 52.860542]
# Kết quả dự báo cho DPM.csv:
#   MSE: 0.27639215698562875
#   R^2: 0.99785027679586
#   Dự báo giá 7 ngày tiếp theo: [35.526302, 34.494457, 34.993233, 34.152863, 34.09793, 34.140896, 33.990967]
# Kết quả dự báo cho DPR.csv:
#   MSE: 0.1352366648104668
#   R^2: 0.9988099014313735
#   Dự báo giá 7 ngày tiếp theo: [42.43977, 42.58375, 42.080536, 42.034416, 42.251873, 42.13623, 41.008553]
# Kết quả dự báo cho DQC.csv:
#   MSE: 0.3405294924193073
#   R^2: 0.99738028772973
#   Dự báo giá 7 ngày tiếp theo: [13.58797, 13.688538, 13.691062, 13.708155, 13.842141, 13.816517, 14.052162]
# Kết quả dự báo cho DRC.csv:
#   MSE: 0.12907769100864594
#   R^2: 0.9943308237153381
#   Dự báo giá 7 ngày tiếp theo: [32.10378, 32.36892, 32.07419, 32.454433, 32.775436, 32.916927, 32.03864]
# Kết quả dự báo cho DRH.csv:
#   MSE: 0.10615607329480885
#   R^2: 0.9975292712982665
#   Dự báo giá 7 ngày tiếp theo: [1.9184923, 1.9104311, 1.9104311, 1.9104311, 1.9136566, 2.085659, 1.9136566]
# Kết quả dự báo cho DRL.csv:
#   MSE: 0.15833923735555058
#   R^2: 0.9993943216078903
#   Dự báo giá 7 ngày tiếp theo: [62.324245, 62.382015, 62.258385, 62.273647, 62.063404, 62.393, 62.520664]
# Kết quả dự báo cho DSE.csv:
#   MSE: 0.16060099117453044
#   R^2: 0.8450456943725531
#   Dự báo giá 7 ngày tiếp theo: [25.351154, 25.643908, 25.476337, 25.164165, 25.155746, 25.162104, 24.41549]
# Kết quả dự báo cho DSN.csv:
#   MSE: 0.175775990966158
#   R^2: 0.9973478784319743
#   Dự báo giá 7 ngày tiếp theo: [55.213303, 55.60427, 55.984238, 55.519012, 56.079887, 56.128754, 56.18911]
# Kết quả dự báo cho DTA.csv:
#   MSE: 0.05307599239786677
#   R^2: 0.9974809531827203
#   Dự báo giá 7 ngày tiếp theo: [3.8242316, 3.810569, 3.7697656, 3.8058035, 3.8058035, 3.8056014, 3.8058035]
# Kết quả dự báo cho DTL.csv:
#   MSE: 0.23296571864305415
#   R^2: 0.9986917254752272
#   Dự báo giá 7 ngày tiếp theo: [11.932852, 11.182376, 10.497659, 9.670136, 9.643969, 9.643969, 9.654592]
# Kết quả dự báo cho DTT.csv:
#   MSE: 0.03734944885440535
#   R^2: 0.9976431582385311
#   Dự báo giá 7 ngày tiếp theo: [18.97777, 19.437243, 19.437243, 19.52543, 19.52543, 19.52543, 19.52543]
# Kết quả dự báo cho DVP.csv:
#   MSE: 0.26116025928976533
#   R^2: 0.9983182813552379
#   Dự báo giá 7 ngày tiếp theo: [74.05962, 73.04822, 73.69826, 73.04822, 74.22995, 73.66685, 73.68285]
# Kết quả dự báo cho DXG.csv:
#   MSE: 0.21531525460621886
#   R^2: 0.9965017020224107
#   Dự báo giá 7 ngày tiếp theo: [15.798256, 15.474759, 14.815352, 14.699241, 14.3439045, 14.073611, 13.644256]
# Kết quả dự báo cho DXS.csv:
#   MSE: 0.08090721723475927
#   R^2: 0.9974493422652901
#   Dự báo giá 7 ngày tiếp theo: [5.9765115, 5.849475, 5.93715, 5.772427, 5.687913, 5.5963907, 5.494077]
# Kết quả dự báo cho DXV.csv:
#   MSE: 0.01959444397775749
#   R^2: 0.9853943138857226
#   Dự báo giá 7 ngày tiếp theo: [3.8189378, 3.866008, 3.8066452, 3.8411007, 3.841749, 3.873661, 3.863843]
# Kết quả dự báo cho E1VFVN30.csv:
#   MSE: 0.036557845780252014
#   R^2: 0.9983980237801803
#   Dự báo giá 7 ngày tiếp theo: [22.956646, 23.180885, 23.095078, 23.173004, 23.0836, 23.006546, 22.909548]
# Kết quả dự báo cho EIB.csv:
#   MSE: 0.054456966676100414
#   R^2: 0.9977341835121175
#   Dự báo giá 7 ngày tiếp theo: [17.182253, 17.241865, 17.004898, 16.743126, 16.786287, 16.487803, 16.410635]
# Kết quả dự báo cho ELC.csv:
#   MSE: 0.05379973840181042
#   R^2: 0.9980790120092172
#   Dự báo giá 7 ngày tiếp theo: [24.427708, 24.358036, 24.39419, 24.53166, 24.39419, 24.132418, 24.185781]
# Kết quả dự báo cho EVE.csv:
#   MSE: 0.06861687552143059
#   R^2: 0.9915164449888098
#   Dự báo giá 7 ngày tiếp theo: [11.166264, 11.181696, 11.022659, 10.948655, 10.968606, 10.844157, 10.755306]
# Kết quả dự báo cho EVF.csv:
#   MSE: 0.04218583758508973
#   R^2: 0.9974357311039465
#   Dự báo giá 7 ngày tiếp theo: [11.522639, 11.521924, 11.671021, 11.715971, 11.668463, 11.67581, 11.650344]
# Kết quả dự báo cho EVG.csv:
#   MSE: 0.025145029973724805
#   R^2: 0.997574665656509
#   Dự báo giá 7 ngày tiếp theo: [7.0412264, 7.032614, 6.948507, 6.9558787, 6.9430842, 6.769843, 6.8103323]
# Kết quả dự báo cho FCM.csv:
#   MSE: 0.017094309932569444
#   R^2: 0.9936526048976853
#   Dự báo giá 7 ngày tiếp theo: [3.3558664, 3.374552, 3.3669314, 3.4084897, 3.3811102, 3.3909454, 3.4091434]
# Kết quả dự báo cho FCN.csv:
#   MSE: 0.09616171059771544
#   R^2: 0.9935027672824501
#   Dự báo giá 7 ngày tiếp theo: [12.765401, 12.7254305, 12.563817, 12.373137, 12.2466955, 12.101117, 12.077796]
# Kết quả dự báo cho FDC.csv:
#   MSE: 0.17763486783276364
#   R^2: 0.9947523563116997
#   Dự báo giá 7 ngày tiếp theo: [13.90319, 13.807445, 13.940792, 13.893319, 13.863627, 13.890658, 13.895234]
# Kết quả dự báo cho FIR.csv:
#   MSE: 0.0585999641791891
#   R^2: 0.9993783546232325
#   Dự báo giá 7 ngày tiếp theo: [6.4351172, 6.4891047, 6.4843435, 6.474207, 6.5171423, 6.4891047, 6.4775305]
# Kết quả dự báo cho FIT.csv:
#   MSE: 0.04293213450516452
#   R^2: 0.9963936125759153
#   Dự báo giá 7 ngày tiếp theo: [4.517593, 4.5391216, 4.4975567, 4.505133, 4.5055075, 4.523169, 4.505133]
# Kết quả dự báo cho FMC.csv:
#   MSE: 0.32539634109014837
#   R^2: 0.9986542902756019
#   Dự báo giá 7 ngày tiếp theo: [46.768326, 46.937546, 47.4176, 47.24922, 47.125957, 47.200527, 47.002113]
# Kết quả dự báo cho FPT.csv:
#   MSE: 0.4771311375814536
#   R^2: 0.9994220647852826
#   Dự báo giá 7 ngày tiếp theo: [135.18652, 133.71495, 133.71495, 135.18652, 135.18652, 138.45123, 139.35025]
# Kết quả dự báo cho FRT.csv:
#   MSE: 1.4561483835703097
#   R^2: 0.9992607538476872
#   Dự báo giá 7 ngày tiếp theo: [180.4951, 182.37859, 182.34196, 182.24683, 181.09377, 182.30957, 182.30957]
# Kết quả dự báo cho FTS.csv:
#   MSE: 0.20756100802619196
#   R^2: 0.9985893474820846
#   Dự báo giá 7 ngày tiếp theo: [44.71249, 44.198574, 42.98149, 42.826763, 42.24424, 41.398315, 42.070805]
# Kết quả dự báo cho FUCTVGF3.csv:
#   MSE: 0.023199782864436698
#   R^2: 0.9915934991461428
#   Dự báo giá 7 ngày tiếp theo: [13.650106, 13.75902, 13.75902, 13.75902, 13.75902, 13.75902, 13.95347]
# Kết quả dự báo cho FUCTVGF4.csv:
#   MSE: 0.03876259128993204
#   R^2: 0.9910969597792653
#   Dự báo giá 7 ngày tiếp theo: [13.750035, 13.599946, 13.599946, 13.599946, 13.560013, 13.560013, 13.560013]
# Kết quả dự báo cho FUCTVGF5.csv:
#   MSE: 0.01797759797533217
#   R^2: 0.7023576494150302
#   Dự báo giá 7 ngày tiếp theo: [11.000026, 11.000026, 11.000026, 11.000026, 11.099974, 11.099974, 11.099974]
# Kết quả dự báo cho FUCVREIT.csv:
#   MSE: 0.05664294008120402
#   R^2: 0.9912054745632711
#   Dự báo giá 7 ngày tiếp theo: [5.6967545, 5.683964, 5.7290587, 5.723824, 5.723824, 5.723824, 5.6787295]
# Kết quả dự báo cho FUEABVND.csv:
#   MSE: 9.950927051249892e-07
#   R^2: nan
#   Dự báo giá 7 ngày tiếp theo: [10.199001, 10.000998, 10.000998, 10.000998, 10.000998, 10.000998, 10.000998]
# Kết quả dự báo cho FUEBFVND.csv:
#   MSE: 0.008100061798213445
#   R^2: nan
#   Dự báo giá 7 ngày tiếp theo: [11.61, 11.61, 11.61, 11.61, 11.61, 11.61, 11.61]
# Kết quả dự báo cho FUEDCMID.csv:
#   MSE: 0.02554122250199851
#   R^2: 0.9901169105529667
#   Dự báo giá 7 ngày tiếp theo: [11.835545, 11.824988, 11.780328, 11.786803, 11.838969, 11.787692, 11.752234]
# Kết quả dự báo cho FUEFCV50.csv:
#   MSE: 0.24001587997934298
#   R^2: 0.8195947641281551
#   Dự báo giá 7 ngày tiếp theo: [12.329509, 12.315692, 12.3328285, 12.316284, 12.293911, 12.189138, 12.350976]
# Kết quả dự báo cho FUEIP100.csv:
#   MSE: 0.019375905160628187
#   R^2: 0.99027491557659
#   Dự báo giá 7 ngày tiếp theo: [9.16075, 9.15082, 9.161519, 9.178882, 9.140311, 9.16434, 9.178882]
# Kết quả dự báo cho FUEKIV30.csv:
#   MSE: 0.014206048664908618
#   R^2: 0.9862163870613762
#   Dự báo giá 7 ngày tiếp theo: [8.796165, 8.77252, 8.776016, 8.775742, 8.858967, 8.826588, 8.812376]
# Kết quả dự báo cho FUEKIVFS.csv:
#   MSE: 0.017653594307860256
#   R^2: 0.9910833901107997
#   Dự báo giá 7 ngày tiếp theo: [12.478944, 12.664366, 12.685963, 12.65404, 12.661057, 12.65404, 12.65404]
# Kết quả dự báo cho FUEKIVND.csv:
#   MSE: 0.002325789566805272
#   R^2: 0.9841610626068832
#   Dự báo giá 7 ngày tiếp theo: [12.449911, 12.469855, 12.573323, 12.641115, 12.698635, 12.625318, 12.698635]
# Kết quả dự báo cho FUEMAV30.csv:
#   MSE: 0.05853411743659435
#   R^2: 0.9849094478640734
#   Dự báo giá 7 ngày tiếp theo: [15.799436, 15.900588, 15.847639, 15.750398, 15.849474, 15.75109, 15.831985]
# Kết quả dự báo cho FUEMAVND.csv:
#   MSE: 0.05490333519293865
#   R^2: 0.9751644301434014
#   Dự báo giá 7 ngày tiếp theo: [13.869312, 14.134096, 14.244556, 14.244556, 14.247924, 14.247924, 14.247924]
# Kết quả dự báo cho FUESSV30.csv:
#   MSE: 0.07641102240061427
#   R^2: 0.9875668490293996
#   Dự báo giá 7 ngày tiếp theo: [16.360802, 16.466793, 16.434322, 16.339273, 16.430344, 16.603863, 16.39751]
# Kết quả dự báo cho FUESSV50.csv:
#   MSE: 0.10016655045407448
#   R^2: 0.9936053608852782
#   Dự báo giá 7 ngày tiếp theo: [19.712662, 19.472551, 19.403366, 19.600767, 19.538427, 18.674501, 18.650742]
# Kết quả dự báo cho FUESSVFL.csv:
#   MSE: 0.07528039923898606
#   R^2: 0.9959181477323813
#   Dự báo giá 7 ngày tiếp theo: [20.778055, 20.854692, 20.778055, 20.654152, 20.778448, 20.906998, 20.545324]
# Kết quả dự báo cho FUEVFVND.csv:
#   MSE: 0.12855191968196833
#   R^2: 0.9961480208111824
#   Dự báo giá 7 ngày tiếp theo: [32.377487, 32.494392, 32.210987, 32.07832, 32.28987, 32.451885, 32.759274]
# Kết quả dự báo cho FUEVN100.csv:
#   MSE: 0.06182987655593209
#   R^2: 0.9906235794525273
#   Dự báo giá 7 ngày tiếp theo: [17.620577, 17.585741, 17.645317, 17.747786, 17.57688, 17.6833, 17.646866]
# Kết quả dự báo cho GAS.csv:
#   MSE: 0.964522557393329
#   R^2: 0.9973238850299526
#   Dự báo giá 7 ngày tiếp theo: [72.94554, 71.00957, 70.71446, 70.88307, 69.95412, 69.46016, 70.01686]
# Kết quả dự báo cho GDT.csv:
#   MSE: 0.16723039248215074
#   R^2: 0.9977973503053028
#   Dự báo giá 7 ngày tiếp theo: [28.134838, 28.180874, 27.64529, 27.869171, 27.791832, 27.913704, 27.92773]
# Kết quả dự báo cho GEE.csv:
#   MSE: 0.9127912563740695
#   R^2: 0.9567575614568867
#   Dự báo giá 7 ngày tiếp theo: [32.810585, 32.625618, 32.643387, 32.069725, 31.844347, 31.07339, 30.022053]
# Kết quả dự báo cho GEG.csv:
#   MSE: 0.09235579211426641
#   R^2: 0.9945149544128461
#   Dự báo giá 7 ngày tiếp theo: [11.491233, 11.513476, 11.444072, 11.506086, 11.491233, 11.489996, 11.263404]
# Kết quả dự báo cho GEX.csv:
#   MSE: 0.2831695053853722
#   R^2: 0.9947390440078008
#   Dự báo giá 7 ngày tiếp theo: [20.699818, 20.498161, 20.377605, 20.488245, 20.23409, 20.398977, 20.35779]
# Kết quả dự báo cho GIL.csv:
#   MSE: 0.5735455015094971
#   R^2: 0.9978131056109959
#   Dự báo giá 7 ngày tiếp theo: [30.776718, 29.592226, 28.960943, 27.593956, 26.905802, 25.89585, 25.248816]
# Kết quả dự báo cho GMC.csv:
#   MSE: 0.0702496268797601
#   R^2: 0.9971317276051832
#   Dự báo giá 7 ngày tiếp theo: [8.4900675, 8.487249, 8.524904, 8.538687, 8.519972, 8.670294, 8.802185]
# Kết quả dự báo cho GMD.csv:
#   MSE: 0.3548188429070406
#   R^2: 0.9989227301380199
#   Dự báo giá 7 ngày tiếp theo: [78.208984, 78.301956, 78.921005, 78.19564, 78.78432, 78.41605, 78.78582]
# Kết quả dự báo cho GMH.csv:
#   MSE: 0.04475308063694062
#   R^2: 0.9954044380083502
#   Dự báo giá 7 ngày tiếp theo: [8.989219, 8.994744, 9.110247, 9.265754, 9.249529, 9.246308, 9.289168]
# Kết quả dự báo cho GSP.csv:
#   MSE: 0.022550170375786553
#   R^2: 0.9963932006170602
#   Dự báo giá 7 ngày tiếp theo: [12.824514, 12.787852, 12.781133, 12.899621, 12.794361, 12.755005, 12.755005]
# Kết quả dự báo cho GTA.csv:
#   MSE: 0.06258242716032991
#   R^2: 0.9908998697180915
#   Dự báo giá 7 ngày tiếp theo: [10.972902, 10.953686, 11.126852, 11.201893, 11.1531315, 11.028321, 11.067945]
# Kết quả dự báo cho GVR.csv:
#   MSE: 0.22518667857342867
#   R^2: 0.997563690746476
#   Dự báo giá 7 ngày tiếp theo: [35.578163, 35.343033, 35.63811, 35.189625, 34.336826, 34.29532, 33.78929]
# Kết quả dự báo cho HAG.csv:
#   MSE: 0.03287096323164743
#   R^2: 0.9979351781671114
#   Dự báo giá 7 ngày tiếp theo: [10.543961, 10.371197, 10.18294, 10.010786, 9.863654, 9.750171, 9.717538]
# Kết quả dự báo cho HAH.csv:
#   MSE: 0.28150280917244874
#   R^2: 0.9982186873029938
#   Dự báo giá 7 ngày tiếp theo: [39.8842, 39.811234, 39.806084, 40.016735, 39.694077, 39.771828, 40.016735]
# Kết quả dự báo cho HAP.csv:
#   MSE: 0.013959775571627716
#   R^2: 0.9980704640372098
#   Dự báo giá 7 ngày tiếp theo: [4.248706, 4.181717, 4.1584687, 4.1614184, 4.1849732, 4.158615, 4.1584687]
# Kết quả dự báo cho HAR.csv:
#   MSE: 0.03342503753500805
#   R^2: 0.9941002155790649
#   Dự báo giá 7 ngày tiếp theo: [3.6787055, 3.634597, 3.5657513, 3.4663212, 3.3682337, 3.3558064, 3.282191]
# Kết quả dự báo cho HAS.csv:
#   MSE: 0.030528775041607878
#   R^2: 0.9951256649595182
#   Dự báo giá 7 ngày tiếp theo: [8.463096, 8.415988, 8.439485, 8.335394, 8.358802, 8.358802, 8.442453]
# Kết quả dự báo cho HAX.csv:
#   MSE: 0.04334293165443547
#   R^2: 0.9980566551885746
#   Dự báo giá 7 ngày tiếp theo: [16.898087, 16.757343, 16.765322, 16.626896, 16.458231, 16.49362, 16.52124]
# Kết quả dự báo cho HCD.csv:
#   MSE: 0.015364658269318003
#   R^2: 0.9978551314248063
#   Dự báo giá 7 ngày tiếp theo: [10.317589, 10.269835, 10.331236, 10.277705, 10.121235, 10.274735, 10.310876]
# Kết quả dự báo cho HCM.csv:
#   MSE: 0.08053211782859811
#   R^2: 0.9983143752240446
#   Dự báo giá 7 ngày tiếp theo: [30.494286, 30.494286, 30.475954, 30.475954, 30.41347, 30.261625, 30.41347]
# Kết quả dự báo cho HDB.csv:
#   MSE: 0.04805247525490207
#   R^2: 0.9981323570306984
#   Dự báo giá 7 ngày tiếp theo: [26.849422, 26.864014, 26.755827, 26.840675, 26.957026, 27.012625, 27.10816]
# Kết quả dự báo cho HDC.csv:
#   MSE: 0.3843984794055704
#   R^2: 0.9980091827423405
#   Dự báo giá 7 ngày tiếp theo: [24.502274, 24.809921, 24.691795, 24.699335, 24.51846, 24.326973, 24.047806]
# Kết quả dự báo cho HDG.csv:
#   MSE: 0.13232636350344285
#   R^2: 0.998807548796151
#   Dự báo giá 7 ngày tiếp theo: [28.688353, 28.757622, 28.777386, 28.909075, 27.96511, 28.29805, 28.515532]
# Kết quả dự báo cho HHP.csv:
#   MSE: 0.03723393798923947
#   R^2: 0.9819859722398485
#   Dự báo giá 7 ngày tiếp theo: [9.348376, 9.354661, 9.435376, 9.435961, 9.321975, 9.336083, 9.338138]
# Kết quả dự báo cho HHS.csv:
#   MSE: 0.02397088359201983
#   R^2: 0.9965476878725453
#   Dự báo giá 7 ngày tiếp theo: [8.852014, 8.757495, 8.832513, 8.747461, 8.645517, 8.5448, 8.303578]
# Kết quả dự báo cho HHV.csv:
#   MSE: 0.06580110042918105
#   R^2: 0.9961076170943374
#   Dự báo giá 7 ngày tiếp theo: [12.144576, 12.033691, 11.862367, 11.453385, 11.30588, 11.116563, 10.735523]
# Kết quả dự báo cho HID.csv:
#   MSE: 0.03422503663933487
#   R^2: 0.9977332498579705
#   Dự báo giá 7 ngày tiếp theo: [2.6895769, 2.6907258, 2.6335952, 2.5777571, 2.5265303, 2.4917078, 2.4281902]
# Kết quả dự báo cho HII.csv:
#   MSE: 0.02925435801203511
#   R^2: 0.997745365128641
#   Dự báo giá 7 ngày tiếp theo: [4.8500495, 4.857293, 4.860602, 4.7953343, 4.6747885, 4.6060147, 4.5373945]
# Kết quả dự báo cho HMC.csv:
#   MSE: 0.026617278500781202
#   R^2: 0.9987231058084091
#   Dự báo giá 7 ngày tiếp theo: [10.662771, 10.754783, 10.703489, 10.761902, 10.791703, 10.603175, 10.331878]
# Kết quả dự báo cho HNA.csv:
#   MSE: 0.0643424244585085
#   R^2: 0.9971868291527628
#   Dự báo giá 7 ngày tiếp theo: [25.507427, 25.681662, 25.507427, 25.505892, 25.119722, 25.245537, 25.245537]
# Kết quả dự báo cho HPG.csv:
#   MSE: 0.08157705812508699
#   R^2: 0.9991373876845099
#   Dự báo giá 7 ngày tiếp theo: [25.200325, 24.972727, 25.027504, 25.109758, 25.07435, 25.090536, 25.155367]
# Kết quả dự báo cho HPX.csv:
#   MSE: 0.17622995522530782
#   R^2: 0.9981749542801476
#   Dự báo giá 7 ngày tiếp theo: [5.1571765, 5.109284, 4.962465, 4.779482, 4.7550254, 4.6492066, 4.6509213]
# Kết quả dự báo cho HQC.csv:
#   MSE: 0.009917450676997305
#   R^2: 0.9970512327789672
#   Dự báo giá 7 ngày tiếp theo: [3.450654, 3.4678788, 3.4341562, 3.4626212, 3.4633512, 3.4754097, 3.4765744]
# Kết quả dự báo cho HRC.csv:
#   MSE: 0.9288002129064108
#   R^2: 0.9918169185884805
#   Dự báo giá 7 ngày tiếp theo: [49.30692, 49.46521, 49.875393, 49.875393, 49.562893, 49.923832, 49.80591]
# Kết quả dự báo cho HSG.csv:
#   MSE: 0.11151217997036302
#   R^2: 0.9981803868547339
#   Dự báo giá 7 ngày tiếp theo: [20.105597, 19.98311, 19.641296, 19.650162, 19.770515, 19.66546, 19.65135]
# Kết quả dự báo cho HSL.csv:
#   MSE: 0.03241032316673855
#   R^2: 0.9953339416772088
#   Dự báo giá 7 ngày tiếp theo: [4.5647154, 4.566809, 4.571148, 4.60879, 4.47969, 4.4409103, 4.362742]
# Kết quả dự báo cho HT1.csv:
#   MSE: 0.05858292582446678
#   R^2: 0.9938003226076886
#   Dự báo giá 7 ngày tiếp theo: [12.030337, 12.112443, 12.083689, 12.02963, 11.990244, 11.995244, 11.983315]
# Kết quả dự báo cho HTG.csv:
#   MSE: 0.14830867447205628
#   R^2: 0.9984120847700899
#   Dự báo giá 7 ngày tiếp theo: [43.5742, 43.40935, 43.40935, 43.558872, 43.566563, 43.558926, 43.369526]
# Kết quả dự báo cho HTI.csv:
#   MSE: 0.014860442242919561
#   R^2: 0.9989817170655453
#   Dự báo giá 7 ngày tiếp theo: [15.895394, 15.954296, 15.907541, 15.888359, 15.959379, 16.188868, 16.188868]
# Kết quả dự báo cho HTL.csv:
#   MSE: 0.25957010493240534
#   R^2: 0.9970947170531844
#   Dự báo giá 7 ngày tiếp theo: [18.404444, 18.551329, 18.489737, 18.437187, 18.466036, 18.540564, 18.654814]
# Kết quả dự báo cho HTN.csv:
#   MSE: 0.23907957251658574
#   R^2: 0.9978803249013701
#   Dự báo giá 7 ngày tiếp theo: [9.0000105, 8.510721, 8.4800825, 8.486423, 8.510721, 8.4800825, 8.463861]
# Kết quả dự báo cho HTV.csv:
#   MSE: 0.036879553780902845
#   R^2: 0.9796466792065002
#   Dự báo giá 7 ngày tiếp theo: [9.833132, 9.762951, 9.665424, 9.537816, 9.494609, 9.531958, 9.600072]
# Kết quả dự báo cho HU1.csv:
#   MSE: 0.050946744816802905
#   R^2: 0.991926109130428
#   Dự báo giá 7 ngày tiếp theo: [6.48806, 6.5570474, 6.6038375, 6.7288146, 6.8365407, 6.903257, 7.0254226]
# Kết quả dự báo cho HUB.csv:
#   MSE: 0.11974793486559995
#   R^2: 0.9949674514960584
#   Dự báo giá 7 ngày tiếp theo: [17.328623, 16.949257, 16.45567, 16.24335, 16.152588, 16.104939, 15.928817]
# Kết quả dự báo cho HVH.csv:
#   MSE: 0.03892738411375773
#   R^2: 0.9973287245187831
#   Dự báo giá 7 ngày tiếp theo: [8.668307, 8.613763, 8.64314, 8.555793, 8.609716, 8.441727, 8.470372]
# Kết quả dự báo cho HVN.csv:
#   MSE: 0.242897467743436
#   R^2: 0.9950852641032728
#   Dự báo giá 7 ngày tiếp theo: [21.717539, 21.637074, 21.343897, 21.368738, 21.464445, 21.367838, 21.147144]
# Kết quả dự báo cho HVX.csv:
#   MSE: 0.009356127932132642
#   R^2: 0.9947013297560802
#   Dự báo giá 7 ngày tiếp theo: [2.7447288, 2.7178524, 2.6484003, 2.644826, 2.6343732, 2.63911, 2.6343732]
# Kết quả dự báo cho ICT.csv:
#   MSE: 0.07609923324575081
#   R^2: 0.9904367281575822
#   Dự báo giá 7 ngày tiếp theo: [11.902646, 11.948684, 11.874708, 11.9216385, 11.898938, 11.874708, 11.844837]
# Kết quả dự báo cho IDI.csv:
#   MSE: 0.04936118036455417
#   R^2: 0.9972672093038583
#   Dự báo giá 7 ngày tiếp theo: [9.3546915, 9.382869, 9.486134, 9.453585, 9.426894, 9.374654, 9.482218]
# Kết quả dự báo cho IJC.csv:
#   MSE: 0.06735699213337466
#   R^2: 0.9979146265115861
#   Dự báo giá 7 ngày tiếp theo: [14.062573, 13.871085, 13.73386, 13.80874, 13.750986, 13.863074, 13.830299]
# Kết quả dự báo cho ILB.csv:
#   MSE: 0.17375625793682578
#   R^2: 0.9969802803986565
#   Dự báo giá 7 ngày tiếp theo: [32.635704, 32.162674, 31.447159, 30.802967, 30.172085, 30.258072, 29.806454]
# Kết quả dự báo cho IMP.csv:
#   MSE: 0.10885844752117674
#   R^2: 0.9983976292351645
#   Dự báo giá 7 ngày tiếp theo: [52.387413, 48.33045, 48.33045, 48.33045, 48.33045, 48.33045, 46.961193]
# Kết quả dự báo cho ITA.csv:
#   MSE: 0.0453495333681291
#   R^2: 0.9956229953499802
#   Dự báo giá 7 ngày tiếp theo: [2.8330607, 2.7831178, 2.7949276, 2.7831178, 2.787048, 2.7429879, 2.7062218]
# Kết quả dự báo cho ITC.csv:
#   MSE: 0.04829978426979747
#   R^2: 0.9959424266644397
#   Dự báo giá 7 ngày tiếp theo: [11.3946495, 11.4402075, 11.080017, 10.615788, 10.252373, 10.316569, 10.341199]
# Kết quả dự báo cho ITD.csv:
#   MSE: 0.040212798199647196
#   R^2: 0.9957006974223745
#   Dự báo giá 7 ngày tiếp theo: [12.006126, 11.981574, 11.935029, 12.064023, 12.004223, 11.954871, 12.039585]
# Kết quả dự báo cho JVC.csv:
#   MSE: 0.043077464199871844
#   R^2: 0.9966376238683481
#   Dự báo giá 7 ngày tiếp theo: [3.2945755, 3.2578948, 3.1974614, 3.1510837, 3.0779207, 3.0695448, 3.014884]
# Kết quả dự báo cho KBC.csv:
#   MSE: 0.1992941694584704
#   R^2: 0.9982130636950587
#   Dự báo giá 7 ngày tiếp theo: [26.681717, 26.744383, 26.805693, 26.57166, 26.425436, 26.433977, 26.575233]
# Kết quả dự báo cho KDC.csv:
#   MSE: 0.1354370804091267
#   R^2: 0.9995432151250863
#   Dự báo giá 7 ngày tiếp theo: [54.657986, 54.656364, 55.08561, 55.83959, 56.270603, 56.599503, 56.86887]
# Kết quả dự báo cho KDH.csv:
#   MSE: 0.12907129958838404
#   R^2: 0.9989385544324044
#   Dự báo giá 7 ngày tiếp theo: [37.996876, 37.93247, 37.60946, 37.281345, 37.380463, 37.290604, 37.326126]
# Kết quả dự báo cho KHG.csv:
#   MSE: 0.057035067105122225
#   R^2: 0.9940324289894104
#   Dự báo giá 7 ngày tiếp theo: [5.3790402, 5.388124, 5.413121, 5.4641843, 5.4654117, 5.5242286, 5.526079]
# Kết quả dự báo cho KHP.csv:
#   MSE: 0.040857876224182445
#   R^2: 0.993997341328276
#   Dự báo giá 7 ngày tiếp theo: [9.68137, 9.700042, 9.533315, 9.602151, 9.646154, 9.615496, 9.640387]
# Kết quả dự báo cho KMR.csv:
#   MSE: 0.01291798490687425
#   R^2: 0.9959022088960261
#   Dự báo giá 7 ngày tiếp theo: [3.2208846, 3.1579669, 3.100288, 3.1258154, 3.1070101, 3.1126404, 3.1126404]
# Kết quả dự báo cho KOS.csv:
#   MSE: 0.13063590977934358
#   R^2: 0.9983816944518098
#   Dự báo giá 7 ngày tiếp theo: [39.5047, 39.63297, 39.362564, 39.591644, 39.850883, 39.81688, 39.55504]
# Kết quả dự báo cho KPF.csv:
#   MSE: 0.1022365339696929
#   R^2: 0.9971195581671458
#   Dự báo giá 7 ngày tiếp theo: [2.460938, 2.340773, 2.340773, 2.284377, 2.3017225, 2.24746, 2.24746]
# Kết quả dự báo cho KSB.csv:
#   MSE: 0.18394821424677713
#   R^2: 0.9970932293251303
#   Dự báo giá 7 ngày tiếp theo: [18.385668, 18.174074, 17.998081, 17.726292, 17.662394, 17.711061, 17.684294]
# Kết quả dự báo cho L10.csv:
#   MSE: 0.12572515012073804
#   R^2: 0.9960829993287263
#   Dự báo giá 7 ngày tiếp theo: [22.765245, 22.345882, 22.42455, 22.42455, 22.715954, 22.885038, 22.496058]
# Kết quả dự báo cho LAF.csv:
#   MSE: 0.07103074060742677
#   R^2: 0.9954055413106939
#   Dự báo giá 7 ngày tiếp theo: [17.325367, 17.285234, 17.373272, 17.42929, 17.426712, 17.413404, 17.338675]
# Kết quả dự báo cho LBM.csv:
#   MSE: 0.06708209939660913
#   R^2: 0.9988043600435528
#   Dự báo giá 7 ngày tiếp theo: [26.992891, 26.992891, 26.992891, 26.992891, 26.992891, 26.992891, 26.992891]
# Kết quả dự báo cho LCG.csv:
#   MSE: 0.0383936148957631
#   R^2: 0.9979769673378154
#   Dự báo giá 7 ngày tiếp theo: [10.818484, 10.808086, 10.77735, 10.660424, 10.465908, 10.34875, 10.33882]
# Kết quả dự báo cho LDG.csv:
#   MSE: 0.1304445848916106
#   R^2: 0.9923287818707351
#   Dự báo giá 7 ngày tiếp theo: [1.7770498, 1.7738218, 1.7770498, 1.7770498, 1.8198966, 1.8198966, 1.7974173]
# Kết quả dự báo cho LEC.csv:
#   MSE: 0.127236300995329
#   R^2: 0.9950439718838875
#   Dự báo giá 7 ngày tiếp theo: [6.124915, 6.133097, 6.214413, 6.200182, 6.295728, 6.394086, 6.3932824]
# Kết quả dự báo cho LGC.csv:
#   MSE: 0.5552603231084573
#   R^2: 0.997458016551078
#   Dự báo giá 7 ngày tiếp theo: [60.00448, 60.4574, 60.48406, 60.59937, 61.659073, 60.231995, 60.05279]
# Kết quả dự báo cho LGL.csv:
#   MSE: 0.024932366380520123
#   R^2: 0.9944190767854205
#   Dự báo giá 7 ngày tiếp theo: [2.6663187, 2.6500912, 2.668557, 2.6908872, 2.6681411, 2.6790698, 2.6790698]
# Kết quả dự báo cho LHG.csv:
#   MSE: 0.20346673944456253
#   R^2: 0.998434831597982
#   Dự báo giá 7 ngày tiếp theo: [37.593277, 37.71612, 37.747078, 37.744137, 37.986988, 38.06601, 37.744137]
# Kết quả dự báo cho LIX.csv:
#   MSE: 0.07131374133867936
#   R^2: 0.9979525139314915
#   Dự báo giá 7 ngày tiếp theo: [35.699783, 35.699783, 35.48244, 35.459415, 35.32746, 35.53462, 35.32651]
# Kết quả dự báo cho LM8.csv:
#   MSE: 0.07745108616773416
#   R^2: 0.9927156631615623
#   Dự báo giá 7 ngày tiếp theo: [15.9434185, 15.909999, 16.125265, 16.071154, 16.0727, 16.181025, 16.155136]
# Kết quả dự báo cho LPB.csv:
#   MSE: 0.03916891895716536
#   R^2: 0.9990326221777963
#   Dự báo giá 7 ngày tiếp theo: [30.688255, 30.790974, 30.569895, 30.888388, 30.79078, 30.569895, 30.688255]
# Kết quả dự báo cho LSS.csv:
#   MSE: 0.028920559377770747
#   R^2: 0.9963591764498662
#   Dự báo giá 7 ngày tiếp theo: [12.144094, 11.964966, 11.857393, 11.451218, 11.248881, 11.226573, 11.06096]
# Kết quả dự báo cho MBB.csv:
#   MSE: 0.04096943936467511
#   R^2: 0.9989854170050105
#   Dự báo giá 7 ngày tiếp theo: [24.40486, 24.768404, 24.54979, 24.247826, 24.16058, 23.93413, 23.749672]
# Kết quả dự báo cho MCM.csv:
#   MSE: 0.3076629301731959
#   R^2: 0.9945774903981834
#   Dự báo giá 7 ngày tiếp theo: [36.79025, 37.07418, 37.46244, 37.205246, 37.54403, 37.827713, 37.738895]
# Kết quả dự báo cho MCP.csv:
#   MSE: 0.2785064970555392
#   R^2: 0.9959106681652679
#   Dự báo giá 7 ngày tiếp theo: [28.05565, 28.110004, 28.019312, 27.887283, 27.529297, 27.339378, 27.244608]
# Kết quả dự báo cho MDG.csv:
#   MSE: 0.07122429823820349
#   R^2: 0.9942243946373437
#   Dự báo giá 7 ngày tiếp theo: [11.458818, 11.556052, 11.556052, 11.604885, 11.555044, 11.555044, 11.526854]
# Kết quả dự báo cho MHC.csv:
#   MSE: 0.02457677952357372
#   R^2: 0.9968037908487233
#   Dự báo giá 7 ngày tiếp theo: [7.434538, 7.4614573, 7.4170537, 7.500591, 7.491196, 7.452, 7.4283404]
# Kết quả dự báo cho MIG.csv:
#   MSE: 0.09380221922551751
#   R^2: 0.9968983262902635
#   Dự báo giá 7 ngày tiếp theo: [16.361946, 16.439957, 16.396805, 16.020561, 15.829521, 15.868189, 15.739241]
# Kết quả dự báo cho MSB.csv:
#   MSE: 0.03969968020476012
#   R^2: 0.9904742630792324
#   Dự báo giá 7 ngày tiếp theo: [11.486484, 11.457865, 11.378934, 11.444271, 11.440346, 11.41197, 11.464496]
# Kết quả dự báo cho MSH.csv:
#   MSE: 0.36812381978097464
#   R^2: 0.9966717386832851
#   Dự báo giá 7 ngày tiếp theo: [47.091476, 47.026463, 47.43756, 46.752495, 46.40636, 46.20975, 45.40983]
# Kết quả dự báo cho MSN.csv:
#   MSE: 1.8418318502417619
#   R^2: 0.9975242863789047
#   Dự báo giá 7 ngày tiếp theo: [73.9733, 72.45433, 70.02652, 70.610535, 70.66149, 70.35592, 70.479164]
# Kết quả dự báo cho MWG.csv:
#   MSE: 0.38866538214978186
#   R^2: 0.9988709168572231
#   Dự báo giá 7 ngày tiếp theo: [68.051315, 67.81619, 68.04394, 67.02681, 65.77214, 65.65828, 65.35149]
# Kết quả dự báo cho NAB.csv:
#   MSE: 0.027006093522813863
#   R^2: 0.9967739666607347
#   Dự báo giá 7 ngày tiếp theo: [17.496, 17.496, 17.195257, 16.842686, 16.456457, 16.294125, 16.06779]
# Kết quả dự báo cho NAF.csv:
#   MSE: 0.06952972288228358
#   R^2: 0.9973045355120586
#   Dự báo giá 7 ngày tiếp theo: [18.85154, 19.164652, 19.127394, 19.007505, 19.117504, 19.212814, 19.033815]
# Kết quả dự báo cho NAV.csv:
#   MSE: 0.0720650244440227
#   R^2: 0.9975276565816928
#   Dự báo giá 7 ngày tiếp theo: [18.333061, 17.216463, 17.354181, 17.106638, 17.115808, 17.296139, 17.394417]
# Kết quả dự báo cho NBB.csv:
#   MSE: 0.24861290542442954
#   R^2: 0.9945830060355586
#   Dự báo giá 7 ngày tiếp theo: [21.980082, 21.578533, 21.553192, 21.03381, 21.079048, 21.072979, 20.920502]
# Kết quả dự báo cho NCT.csv:
#   MSE: 0.4756753935415679
#   R^2: 0.9983037888472596
#   Dự báo giá 7 ngày tiếp theo: [113.49255, 113.32002, 103.6059, 103.51461, 103.56188, 103.5505, 103.29286]
# Kết quả dự báo cho NHA.csv:
#   MSE: 0.4244788576953684
#   R^2: 0.9976583650206858
#   Dự báo giá 7 ngày tiếp theo: [24.939243, 24.268837, 23.830383, 23.454332, 22.45855, 21.335278, 21.25287]
# Kết quả dự báo cho NHH.csv:
#   MSE: 0.5163655579170405
#   R^2: 0.995707552256553
#   Dự báo giá 7 ngày tiếp theo: [14.33956, 14.100512, 14.153951, 14.18319, 14.276556, 14.1792965, 13.978669]
# Kết quả dự báo cho NHT.csv:
#   MSE: 0.16838132266130093
#   R^2: 0.9925952348191129
#   Dự báo giá 7 ngày tiếp theo: [12.318037, 12.317828, 12.385673, 12.434807, 12.54795, 12.541086, 12.563915]
# Kết quả dự báo cho NKG.csv:
#   MSE: 0.16122478559649525
#   R^2: 0.9981125880405486
#   Dự báo giá 7 ngày tiếp theo: [21.45471, 21.231714, 21.097363, 20.687582, 20.205492, 19.753601, 19.47137]
# Kết quả dự báo cho NLG.csv:
#   MSE: 0.3290763185985596
#   R^2: 0.9979003780866474
#   Dự báo giá 7 ngày tiếp theo: [42.078274, 41.59619, 41.90654, 42.078274, 41.98371, 42.057644, 42.297184]
# Kết quả dự báo cho NNC.csv:
#   MSE: 0.10785683432059599
#   R^2: 0.9983787083900693
#   Dự báo giá 7 ngày tiếp theo: [22.728508, 22.520403, 22.634308, 22.744259, 22.77728, 22.95794, 22.85744]
# Kết quả dự báo cho NO1.csv:
#   MSE: 0.025522883966284098
#   R^2: 0.9856609116377291
#   Dự báo giá 7 ngày tiếp theo: [7.7799077, 7.5812793, 7.580841, 7.602891, 7.581283, 7.634408, 7.6298647]
# Kết quả dự báo cho NSC.csv:
#   MSE: 1.0314316916391328
#   R^2: 0.9836143555425226
#   Dự báo giá 7 ngày tiếp theo: [79.759674, 80.13773, 81.34645, 81.77901, 81.64412, 81.68834, 81.87564]
# Kết quả dự báo cho NT2.csv:
#   MSE: 0.07232610162517433
#   R^2: 0.9966609462369759
#   Dự báo giá 7 ngày tiếp theo: [20.016464, 20.09223, 20.210217, 20.291008, 20.264616, 20.283289, 20.344833]
# Kết quả dự báo cho NTL.csv:
#   MSE: 0.04004809498806603
#   R^2: 0.9984912265899086
#   Dự báo giá 7 ngày tiếp theo: [21.308115, 21.28883, 20.515137, 20.627743, 20.613676, 20.613676, 20.60717]
# Kết quả dự báo cho NVL.csv:
#   MSE: 0.4101503408855552
#   R^2: 0.9991454938151103
#   Dự báo giá 7 ngày tiếp theo: [11.304726, 11.229976, 11.239608, 10.965234, 10.581422, 10.581422, 10.581422]
# Kết quả dự báo cho NVT.csv:
#   MSE: 0.12535260831724412
#   R^2: 0.9925438162383702
#   Dự báo giá 7 ngày tiếp theo: [7.988415, 7.827327, 7.796229, 7.8046446, 7.822603, 7.813862, 7.760185]
# Kết quả dự báo cho OCB.csv:
#   MSE: 0.04470195758537031
#   R^2: 0.9893815792612403
#   Dự báo giá 7 ngày tiếp theo: [11.596427, 11.728703, 11.631533, 11.710682, 11.6196575, 11.692038, 11.713901]
# Kết quả dự báo cho OGC.csv:
#   MSE: 0.042690715101739427
#   R^2: 0.9964342636902773
#   Dự báo giá 7 ngày tiếp theo: [4.4261594, 4.4451656, 4.4261594, 4.4226193, 4.4261594, 4.4226193, 4.4261594]
# Kết quả dự báo cho OPC.csv:
#   MSE: 0.09495688060821438
#   R^2: 0.9959421755688211
#   Dự báo giá 7 ngày tiếp theo: [23.88727, 24.180645, 24.113821, 24.355886, 24.370985, 24.24743, 24.287346]
# Kết quả dự báo cho ORS.csv:
#   MSE: 0.04037093446393985
#   R^2: 0.9990257144816124
#   Dự báo giá 7 ngày tiếp theo: [12.579863, 12.505912, 12.095621, 11.87097, 11.838669, 11.583897, 11.309898]
# Kết quả dự báo cho PAC.csv:
#   MSE: 0.27774966803068224
#   R^2: 0.995539931156294
#   Dự báo giá 7 ngày tiếp theo: [42.850285, 42.798485, 42.268948, 41.76822, 40.97711, 40.939842, 40.939842]
# Kết quả dự báo cho PAN.csv:
#   MSE: 0.1938203464744362
#   R^2: 0.9943674844400651
#   Dự báo giá 7 ngày tiếp theo: [23.614746, 23.70144, 23.445192, 23.681286, 23.500551, 23.383121, 23.45472]
# Kết quả dự báo cho PC1.csv:
#   MSE: 0.20094094048461894
#   R^2: 0.996946721571718
#   Dự báo giá 7 ngày tiếp theo: [28.745426, 28.238047, 27.563173, 26.791506, 26.478579, 26.357798, 26.291437]
# Kết quả dự báo cho PDN.csv:
#   MSE: 1.6850114371709095
#   R^2: 0.9983277906001603
#   Dự báo giá 7 ngày tiếp theo: [110.851135, 111.25156, 111.78996, 112.89625, 113.5547, 113.62363, 114.09575]
# Kết quả dự báo cho PDR.csv:
#   MSE: 0.19268008716940105
#   R^2: 0.9994225590393677
#   Dự báo giá 7 ngày tiếp theo: [22.38215, 21.393377, 20.6594, 20.122158, 19.680508, 19.518526, 19.298315]
# Kết quả dự báo cho PET.csv:
#   MSE: 0.2212127630029609
#   R^2: 0.9981662169442101
#   Dự báo giá 7 ngày tiếp theo: [26.317753, 25.453197, 25.326572, 25.080786, 24.71353, 24.513025, 24.311033]
# Kết quả dự báo cho PGC.csv:
#   MSE: 0.03181897107335433
#   R^2: 0.9983894952467554
#   Dự báo giá 7 ngày tiếp theo: [14.41104, 14.41055, 14.343205, 14.323698, 14.470062, 14.543085, 14.672748]
# Kết quả dự báo cho PGD.csv:
#   MSE: 0.23994045751673013
#   R^2: 0.9938880682998256
#   Dự báo giá 7 ngày tiếp theo: [30.868885, 30.872902, 30.994198, 30.94655, 31.056347, 30.94655, 31.06249]
# Kết quả dự báo cho PGI.csv:
#   MSE: 0.0778318170690245
#   R^2: 0.9979983602377731
#   Dự báo giá 7 ngày tiếp theo: [23.417221, 23.306751, 23.6545, 23.42718, 23.424078, 23.71204, 23.666636]
# Kết quả dự báo cho PGV.csv:
#   MSE: 0.1156576586993499
#   R^2: 0.9979228542656096
#   Dự báo giá 7 ngày tiếp theo: [21.501944, 21.330423, 21.537064, 21.5673, 21.766346, 21.544172, 21.620354]
# Kết quả dự báo cho PHC.csv:
#   MSE: 0.022430948492998697
#   R^2: 0.9974920832289358
#   Dự báo giá 7 ngày tiếp theo: [5.501457, 5.5113473, 5.497902, 5.5156736, 5.4891863, 5.429643, 5.393184]
# Kết quả dự báo cho PHR.csv:
#   MSE: 0.5844855177723116
#   R^2: 0.9985567306133609
# ...
# Kết quả dự báo cho TCH.csv:
#   MSE: 0.08329376723504187
#   R^2: 0.9936625459415064
#   Dự báo giá 7 ngày tiếp theo: [17.737398, 17.769333, 17.539778, 17.649382, 17.51567, 17.50277, 17.435652]
# Kết quả dự báo cho TCI.csv:
#   MSE: 0.06278082503060073
#   R^2: 0.9965273053322357
#   Dự báo giá 7 ngày tiếp theo: [8.992763, 8.972146, 9.183039, 9.117182, 9.119819, 8.952603, 8.954421]
# Kết quả dự báo cho TCL.csv:
#   MSE: 0.07119326696481763
#   R^2: 0.9994061810509972
#   Dự báo giá 7 ngày tiếp theo: [35.0204, 34.92793, 34.896103, 34.778885, 34.70241, 34.667564, 34.93426]
# Kết quả dự báo cho TCM.csv:
#   MSE: 0.3025103005133811
#   R^2: 0.9989203052191533
#   Dự báo giá 7 ngày tiếp theo: [47.035034, 46.951607, 47.342945, 47.25246, 46.8827, 46.792267, 47.076904]
# Kết quả dự báo cho TCO.csv:
#   MSE: 0.07483107163611792
#   R^2: 0.9958301541579202
#   Dự báo giá 7 ngày tiếp theo: [17.188997, 17.898994, 18.477486, 18.357315, 18.359524, 18.359524, 18.359524]
# Kết quả dự báo cho TCR.csv:
#   MSE: 0.013757199088909702
#   R^2: 0.995510541986544
#   Dự báo giá 7 ngày tiếp theo: [3.355952, 3.3347495, 3.3168433, 3.275296, 3.256842, 3.2792566, 3.2387083]
# Kết quả dự báo cho TCT.csv:
#   MSE: 0.3770859322878481
#   R^2: 0.9961051302989389
#   Dự báo giá 7 ngày tiếp theo: [17.720104, 17.95932, 17.961271, 18.329075, 18.347887, 18.349838, 18.347887]
# Kết quả dự báo cho TDC.csv:
#   MSE: 0.08912647407049691
#   R^2: 0.997674354677643
#   Dự báo giá 7 ngày tiếp theo: [10.994631, 10.676638, 10.045876, 9.817356, 9.578984, 9.552124, 9.619375]
# Kết quả dự báo cho TDG.csv:
#   MSE: 0.01866972751869975
#   R^2: 0.9974818258109196
#   Dự báo giá 7 ngày tiếp theo: [5.2747803, 5.161569, 5.016334, 4.9328566, 4.845575, 4.7471604, 4.7640476]
# Kết quả dự báo cho TDH.csv:
#   MSE: 0.033645251214633215
#   R^2: 0.9941023710666645
#   Dự báo giá 7 ngày tiếp theo: [2.8946474, 2.882996, 2.882996, 2.7988174, 2.7236204, 2.7589896, 2.7663596]
# Kết quả dự báo cho TDM.csv:
#   MSE: 0.35398771468426726
#   R^2: 0.9969633946673713
#   Dự báo giá 7 ngày tiếp theo: [48.534107, 47.743793, 47.743793, 47.4127, 47.652874, 47.652874, 47.59075]
# Kết quả dự báo cho TDP.csv:
#   MSE: 0.17042505577743386
#   R^2: 0.9969975223995268
#   Dự báo giá 7 ngày tiếp theo: [35.56057, 35.342793, 35.37329, 35.395493, 35.462257, 35.34275, 34.51339]
# Kết quả dự báo cho TDW.csv:
#   MSE: 0.23150169178029406
#   R^2: 0.9978171642493029
#   Dự báo giá 7 ngày tiếp theo: [48.188866, 48.4969, 48.51426, 49.420383, 49.750996, 49.599697, 49.451466]
# Kết quả dự báo cho TEG.csv:
#   MSE: 0.02860565299707607
#   R^2: 0.9971154322817463
#   Dự báo giá 7 ngày tiếp theo: [8.50211, 8.568323, 8.678071, 8.710542, 8.758326, 8.760709, 8.831803]
# Kết quả dự báo cho THG.csv:
#   MSE: 0.16315975624658663
#   R^2: 0.9990534986160922
#   Dự báo giá 7 ngày tiếp theo: [44.823406, 44.823406, 44.823406, 44.942097, 45.650455, 46.27722, 47.017555]
# Kết quả dự báo cho TIP.csv:
#   MSE: 0.18065534918246812
#   R^2: 0.9979785308841114
#   Dự báo giá 7 ngày tiếp theo: [23.547497, 23.42505, 23.560915, 23.836657, 23.344164, 23.072046, 23.086817]
# Kết quả dự báo cho TIX.csv:
#   MSE: 0.1855107035865229
#   R^2: 0.9966324110369675
#   Dự báo giá 7 ngày tiếp theo: [35.480286, 35.480286, 35.00715, 35.092735, 35.105503, 35.105503, 34.557434]
# Kết quả dự báo cho TLD.csv:
#   MSE: 0.03411570875333871
#   R^2: 0.9951147078794895
#   Dự báo giá 7 ngày tiếp theo: [5.5033956, 5.4282374, 5.3943834, 5.3933897, 5.258645, 5.2515707, 5.2278447]
# Kết quả dự báo cho TLG.csv:
#   MSE: 0.3432983983455719
#   R^2: 0.997155713205496
#   Dự báo giá 7 ngày tiếp theo: [52.80878, 52.70088, 53.275955, 53.680435, 52.720276, 52.04179, 51.042587]
# Kết quả dự báo cho TLH.csv:
#   MSE: 0.03285168163055497
#   R^2: 0.9980402474854491
#   Dự báo giá 7 ngày tiếp theo: [5.493806, 5.4381824, 5.444813, 5.444813, 5.4437547, 5.3754373, 5.3698854]
# Kết quả dự báo cho TMP.csv:
#   MSE: 0.2625646034755016
#   R^2: 0.9991145202340863
#   Dự báo giá 7 ngày tiếp theo: [66.155334, 66.758385, 67.22813, 68.08061, 68.040764, 68.519295, 68.66899]
# Kết quả dự báo cho TMS.csv:
#   MSE: 0.5218898139146679
#   R^2: 0.9979407736059056
#   Dự báo giá 7 ngày tiếp theo: [49.82927, 49.81329, 50.492813, 50.93722, 50.39736, 50.385475, 49.543674]
# Kết quả dự báo cho TMT.csv:
#   MSE: 0.2297598419850876
#   R^2: 0.9974741600451171
#   Dự báo giá 7 ngày tiếp theo: [6.934549, 6.8052554, 6.79574, 6.7235985, 6.6107616, 6.5721526, 6.6230507]
# Kết quả dự báo cho TN1.csv:
#   MSE: 0.1384617763001694
#   R^2: 0.9936230504491532
#   Dự báo giá 7 ngày tiếp theo: [11.230791, 11.1142235, 11.002911, 10.8592205, 10.8592205, 10.8592205, 10.8592205]
# Kết quả dự báo cho TNA.csv:
#   MSE: 0.03793416147150785
#   R^2: 0.9965907997473672
#   Dự báo giá 7 ngày tiếp theo: [3.7872345, 3.7749817, 3.7753656, 3.77384, 3.8119853, 3.805964, 3.7702093]
# Kết quả dự báo cho TNC.csv:
#   MSE: 0.6725123220643665
#   R^2: 0.9981660881157668
#   Dự báo giá 7 ngày tiếp theo: [37.526722, 37.57259, 37.57259, 37.52109, 37.438843, 37.52109, 37.10804]
# Kết quả dự báo cho TNH.csv:
#   MSE: 0.15638860522590506
#   R^2: 0.9929286833462923
#   Dự báo giá 7 ngày tiếp theo: [21.574217, 21.674574, 21.556446, 21.6637, 21.357363, 21.309774, 20.942043]
# Kết quả dự báo cho TNI.csv:
#   MSE: 0.01744466091070251
#   R^2: 0.9980859363329727
#   Dự báo giá 7 ngày tiếp theo: [2.3521, 2.329934, 2.3392975, 2.335533, 2.3343527, 2.3331852, 2.3411465]
# Kết quả dự báo cho TNT.csv:
#   MSE: 0.056884862092273086
#   R^2: 0.9987185409481254
#   Dự báo giá 7 ngày tiếp theo: [4.1111665, 4.151804, 4.1939445, 4.1705914, 4.141394, 4.0828075, 4.056996]
# Kết quả dự báo cho TPB.csv:
#   MSE: 0.06487922647447611
#   R^2: 0.9975532746921283
#   Dự báo giá 7 ngày tiếp theo: [18.251925, 18.055471, 17.886005, 17.795414, 17.510794, 17.420143, 17.322248]
# Kết quả dự báo cho TPC.csv:
#   MSE: 0.026413964546197613
#   R^2: 0.9930895745432909
#   Dự báo giá 7 ngày tiếp theo: [6.103908, 6.0676775, 6.00274, 6.035019, 5.968829, 5.9605055, 6.0479636]
# Kết quả dự báo cho TRA.csv:
#   MSE: 0.8335856673807363
#   R^2: 0.9973651102992024
#   Dự báo giá 7 ngày tiếp theo: [78.238205, 78.34753, 78.35038, 78.24385, 78.35038, 79.506836, 80.119606]
# Kết quả dự báo cho TRC.csv:
#   MSE: 0.26295586929454423
#   R^2: 0.9971225039217725
#   Dự báo giá 7 ngày tiếp theo: [40.34114, 40.288597, 40.292152, 40.300415, 40.205666, 40.137775, 39.600166]
# Kết quả dự báo cho TSC.csv:
#   MSE: 0.06291677426063483
#   R^2: 0.9972495134926243
#   Dự báo giá 7 ngày tiếp theo: [3.0135264, 2.9621725, 2.9445407, 2.8330166, 2.7622452, 2.6765997, 2.5317585]
# Kết quả dự báo cho TTA.csv:
#   MSE: 0.05590220918467732
#   R^2: 0.9900748824238756
#   Dự báo giá 7 ngày tiếp theo: [10.018401, 9.9901285, 9.893488, 9.616062, 8.936824, 8.834667, 8.748294]
# Kết quả dự báo cho TTE.csv:
#   MSE: 0.07128567979565975
#   R^2: 0.988904003501607
#   Dự báo giá 7 ngày tiếp theo: [18.809196, 18.529163, 18.438509, 18.42587, 18.42587, 18.439068, 18.42587]
# Kết quả dự báo cho TTF.csv:
#   MSE: 0.09086661959709398
#   R^2: 0.9983093429062367
#   Dự báo giá 7 ngày tiếp theo: [3.4196641, 3.4159882, 3.4028382, 3.4168258, 3.4177556, 3.4107873, 3.323207]
# Kết quả dự báo cho TV2.csv:
#   MSE: 0.22115521631687843
#   R^2: 0.9983925974619321
#   Dự báo giá 7 ngày tiếp theo: [31.625828, 31.406757, 30.783829, 30.913982, 30.559488, 30.219828, 29.77939]
# Kết quả dự báo cho TVB.csv:
#   MSE: 0.07542477406654492
#   R^2: 0.9968470969326764
#   Dự báo giá 7 ngày tiếp theo: [9.111493, 9.046398, 8.939406, 8.76902, 8.803531, 8.791886, 8.769262]
# Kết quả dự báo cho TVS.csv:
#   MSE: 0.2449529933135289
#   R^2: 0.9963466028123723
#   Dự báo giá 7 ngày tiếp theo: [23.724749, 23.713293, 23.328615, 22.973259, 23.139616, 23.139616, 22.973259]
# Kết quả dự báo cho TVT.csv:
#   MSE: 0.08066923317327634
#   R^2: 0.9960862355858473
#   Dự báo giá 7 ngày tiếp theo: [16.013346, 16.332554, 16.42335, 16.487253, 16.702135, 16.646643, 16.752438]
# Kết quả dự báo cho TYA.csv:
#   MSE: 0.022848974102450983
#   R^2: 0.9985220969708813
#   Dự báo giá 7 ngày tiếp theo: [12.758312, 12.631035, 12.562142, 12.632915, 12.551792, 12.551792, 12.617976]
# Kết quả dự báo cho UIC.csv:
#   MSE: 0.28926713618048866
#   R^2: 0.9984585577099891
#   Dự báo giá 7 ngày tiếp theo: [37.871494, 38.251747, 38.30106, 37.981518, 37.828594, 37.286907, 36.99889]
# Kết quả dự báo cho VAF.csv:
#   MSE: 0.0922310835905011
#   R^2: 0.9781392069565992
#   Dự báo giá 7 ngày tiếp theo: [13.859625, 14.062984, 13.648731, 13.800405, 13.819723, 13.773359, 13.681689]
# Kết quả dự báo cho VCA.csv:
#   MSE: 0.07965887126337941
#   R^2: 0.9947678345609849
#   Dự báo giá 7 ngày tiếp theo: [8.692741, 8.838999, 8.948194, 9.003188, 9.086424, 9.139885, 9.200313]
# Kết quả dự báo cho VCB.csv:
#   MSE: 0.4033811629131528
#   R^2: 0.9992917427727709
#   Dự báo giá 7 ngày tiếp theo: [91.45896, 90.750435, 90.59492, 90.51063, 89.77795, 90.79096, 90.43853]
# Kết quả dự báo cho VCF.csv:
#   MSE: 7.1771009465428115
#   R^2: 0.9973491906436326
#   Dự báo giá 7 ngày tiếp theo: [226.0271, 228.42676, 221.67072, 224.25298, 228.39291, 228.31708, 226.50778]
# Kết quả dự báo cho VCG.csv:
#   MSE: 0.13626902965603457
#   R^2: 0.9977764382367583
#   Dự báo giá 7 ngày tiếp theo: [18.493198, 18.295109, 17.908592, 17.342947, 17.21056, 17.154316, 16.829922]
# Kết quả dự báo cho VCI.csv:
#   MSE: 0.25829790127530367
#   R^2: 0.9977851247185612
#   Dự báo giá 7 ngày tiếp theo: [34.47059, 34.299866, 34.549026, 34.45798, 34.566147, 33.9476, 33.492905]
# Kết quả dự báo cho VDP.csv:
#   MSE: 0.20528701422599788
#   R^2: 0.9915696720385324
#   Dự báo giá 7 ngày tiếp theo: [33.944, 34.47774, 34.662445, 34.966488, 34.966488, 34.966488, 34.966488]
# Kết quả dự báo cho VDS.csv:
#   MSE: 0.0424866652878577
#   R^2: 0.9988331138367913
#   Dự báo giá 7 ngày tiếp theo: [21.156904, 20.582832, 19.976957, 19.968393, 19.606745, 19.662968, 19.662968]
# Kết quả dự báo cho VFG.csv:
#   MSE: 0.4991437273879526
#   R^2: 0.9969967257547465
#   Dự báo giá 7 ngày tiếp theo: [70.23614, 70.23614, 70.17475, 70.284874, 71.2476, 71.67848, 73.42036]
# Kết quả dự báo cho VGC.csv:
#   MSE: 0.5829363132006197
#   R^2: 0.9977194571729174
#   Dự báo giá 7 ngày tiếp theo: [43.41876, 42.23737, 42.251076, 42.601192, 42.437782, 41.808754, 42.409058]
# Kết quả dự báo cho VHC.csv:
#   MSE: 0.6664880065051457
#   R^2: 0.9983490774264256
#   Dự báo giá 7 ngày tiếp theo: [71.19989, 71.84599, 72.06498, 72.8023, 72.96111, 72.39975, 72.538795]
# Kết quả dự báo cho VHM.csv:
#   MSE: 0.6383430025285393
#   R^2: 0.9985043391135103
#   Dự báo giá 7 ngày tiếp theo: [43.99106, 43.61518, 43.73708, 43.787437, 43.81586, 43.70414, 43.429695]
# Kết quả dự báo cho VIB.csv:
#   MSE: 0.0944256819234477
#   R^2: 0.9975953083541408
#   Dự báo giá 7 ngày tiếp theo: [18.297987, 18.296497, 18.410088, 18.406502, 18.400896, 18.397429, 18.282915]
# Kết quả dự báo cho VIC.csv:
#   MSE: 0.9200784526220548
#   R^2: 0.9989741820908218
#   Dự báo giá 7 ngày tiếp theo: [42.912525, 43.170532, 42.958218, 43.26313, 43.427376, 43.80604, 43.263958]
# Kết quả dự báo cho VID.csv:
#   MSE: 0.013363935242186145
#   R^2: 0.9964136173687757
#   Dự báo giá 7 ngày tiếp theo: [5.3908124, 5.3533597, 5.371281, 5.3383884, 5.3296695, 5.3355803, 5.269707]
# Kết quả dự báo cho VIP.csv:
#   MSE: 0.01437313362502921
#   R^2: 0.9979940940887948
#   Dự báo giá 7 ngày tiếp theo: [12.956579, 12.689808, 12.6783, 12.678272, 12.682754, 12.6783, 12.678272]
# Kết quả dự báo cho VIX.csv:
#   MSE: 0.028268831757286412
#   R^2: 0.9986959834600974
#   Dự báo giá 7 ngày tiếp theo: [11.360444, 10.812169, 10.636214, 10.636214, 10.645247, 10.67743, 10.655657]
# Kết quả dự báo cho VJC.csv:
#   MSE: 2.985144407414961
#   R^2: 0.993131516696633
#   Dự báo giá 7 ngày tiếp theo: [104.941734, 104.74636, 106.01999, 105.85336, 105.43632, 107.022804, 106.56138]
# Kết quả dự báo cho VMD.csv:
#   MSE: 0.7164506439605475
#   R^2: 0.9795067197180396
#   Dự báo giá 7 ngày tiếp theo: [18.38932, 18.421488, 18.359268, 18.421488, 18.317863, 18.455431, 18.384712]
# Kết quả dự báo cho VND.csv:
#   MSE: 0.07793739302606915
#   R^2: 0.9987023268616367
#   Dự báo giá 7 ngày tiếp theo: [14.577063, 14.630129, 14.854604, 14.56074, 14.854604, 14.663203, 14.402948]
# Kết quả dự báo cho VNE.csv:
#   MSE: 0.04452668201587009
#   R^2: 0.9956080442588132
#   Dự báo giá 7 ngày tiếp theo: [4.2695117, 4.2007146, 4.1450663, 4.1084323, 4.056032, 3.967833, 3.8469405]
# Kết quả dự báo cho VNG.csv:
#   MSE: 0.07427748095145398
#   R^2: 0.9949972136338123
#   Dự báo giá 7 ngày tiếp theo: [8.198775, 8.197995, 8.191237, 8.203621, 8.191237, 8.197902, 8.1299305]
# Kết quả dự báo cho VNL.csv:
#   MSE: 0.036317677468107955
#   R^2: 0.9954887618519185
#   Dự báo giá 7 ngày tiếp theo: [16.24688, 16.361744, 16.455427, 16.39905, 16.39905, 16.44483, 16.425785]
# Kết quả dự báo cho VNM.csv:
#   MSE: 0.5878028354014713
#   R^2: 0.9976830992465751
#   Dự báo giá 7 ngày tiếp theo: [73.064026, 72.82666, 73.22865, 72.88043, 72.69754, 72.04866, 72.96004]
# Kết quả dự báo cho VNS.csv:
#   MSE: 0.03713124709537493
#   R^2: 0.9970605552366607
#   Dự báo giá 7 ngày tiếp theo: [10.370902, 10.321274, 10.321274, 10.348808, 10.342159, 10.377282, 10.296104]
# Kết quả dự báo cho VOS.csv:
#   MSE: 0.07123277142999906
#   R^2: 0.9981323157416773
#   Dự báo giá 7 ngày tiếp theo: [15.946346, 15.680478, 15.443855, 15.286688, 15.277414, 14.309821, 13.71279]
# Kết quả dự báo cho VPB.csv:
#   MSE: 0.05327457432456984
#   R^2: 0.9983141500071945
#   Dự báo giá 7 ngày tiếp theo: [18.714668, 18.535597, 18.572086, 18.372087, 18.274302, 18.07659, 18.261616]
# Kết quả dự báo cho VPD.csv:
#   MSE: 0.07800935156522654
#   R^2: 0.9977095528758547
#   Dự báo giá 7 ngày tiếp theo: [27.4726, 27.409351, 27.409351, 27.38169, 27.41497, 27.41497, 27.41497]
# Kết quả dự báo cho VPG.csv:
#   MSE: 0.10209855268223249
#   R^2: 0.999267003583395
#   Dự báo giá 7 ngày tiếp theo: [12.914176, 12.913876, 12.913876, 12.925419, 12.915468, 12.925419, 12.926454]
# Kết quả dự báo cho VPH.csv:
#   MSE: 0.022904812222273516
#   R^2: 0.9969188108633806
#   Dự báo giá 7 ngày tiếp theo: [8.938764, 8.931519, 8.967762, 9.017309, 8.971729, 8.934041, 8.935991]
# Kết quả dự báo cho VPI.csv:
#   MSE: 0.17372103956631713
#   R^2: 0.9988140158333532
#   Dự báo giá 7 ngày tiếp theo: [57.304237, 57.304237, 57.332024, 57.7549, 57.666405, 58.208427, 57.943996]
# Kết quả dự báo cho VPS.csv:
#   MSE: 0.05417951402209938
#   R^2: 0.988597640197395
#   Dự báo giá 7 ngày tiếp theo: [9.618341, 9.622156, 9.706962, 9.746849, 9.639496, 9.600103, 9.55261]
# Kết quả dự báo cho VRC.csv:
#   MSE: 0.20465427879528608
#   R^2: 0.9956449947078644
#   Dự báo giá 7 ngày tiếp theo: [7.9855833, 8.00129, 7.9984922, 7.932712, 7.98669, 7.964683, 7.964683]
# Kết quả dự báo cho VRE.csv:
#   MSE: 0.21369201083686412
#   R^2: 0.9915337013551412
#   Dự báo giá 7 ngày tiếp theo: [19.42266, 19.285685, 19.314632, 19.105057, 18.996841, 18.91324, 19.006842]
# Kết quả dự báo cho VSC.csv:
#   MSE: 0.09026525553160661
#   R^2: 0.9966467465582493
#   Dự báo giá 7 ngày tiếp theo: [17.174742, 17.137947, 17.08305, 17.044973, 17.156824, 17.062721, 17.020317]
# Kết quả dự báo cho VSH.csv:
#   MSE: 0.12005863385213794
#   R^2: 0.9991147439034872
#   Dự báo giá 7 ngày tiếp theo: [49.99384, 49.768505, 49.600674, 49.186783, 48.952175, 48.798378, 48.61539]
# Kết quả dự báo cho VSI.csv:
#   MSE: 0.10769420025227842
#   R^2: 0.9949707055621051
#   Dự báo giá 7 ngày tiếp theo: [19.994871, 18.354856, 18.305107, 18.463913, 18.11206, 17.501928, 17.728512]
# Kết quả dự báo cho VTB.csv:
#   MSE: 0.06428855048969061
#   R^2: 0.9835485081272968
#   Dự báo giá 7 ngày tiếp theo: [10.592036, 10.579085, 10.60487, 10.547785, 10.488705, 10.413898, 10.546619]
# Kết quả dự báo cho VTO.csv:
#   MSE: 0.016279381722819012
#   R^2: 0.9976037037259138
#   Dự báo giá 7 ngày tiếp theo: [12.89211, 12.965809, 13.018961, 12.9672985, 12.9672985, 12.738764, 12.721308]
# Kết quả dự báo cho VTP.csv:
#   MSE: 1.328706333919131
#   R^2: 0.9935792575787425
#   Dự báo giá 7 ngày tiếp theo: [80.68969, 81.04725, 80.794334, 80.764824, 80.764824, 80.20327, 80.20327]
# Kết quả dự báo cho YBM.csv:
#   MSE: 0.04151243558395556
#   R^2: 0.9938492031453398
#   Dự báo giá 7 ngày tiếp theo: [10.807002, 11.061369, 11.149062, 11.177978, 11.183124, 11.177978, 11.177978]
# Kết quả dự báo cho YEG.csv:
#   MSE: 2.5637942602620236
#   R^2: 0.9982037338327415
#   Dự báo giá 7 ngày tiếp theo: [9.296467, 9.282138, 9.239628, 9.138789, 9.086438, 9.071244, 9.075597]
