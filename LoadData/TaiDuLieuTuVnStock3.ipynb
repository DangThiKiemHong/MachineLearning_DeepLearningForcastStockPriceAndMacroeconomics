# %%
pip install -U vnstock3

# %%
from vnstock3 import Vnstock

# %%
stock = Vnstock().stock(symbol='ACB', source='VCI')
# Out:
# 2024-09-19 05:57:14,456 - vnstock3.common.data.data_explorer - WARNING - Thông tin niêm yết & giao dịch sẽ được truy xuất từ TCBS

# %%
stock.listing.symbols_by_group('HOSE')
# Out:
# 0      AAA
# 1      AAM
# 2      AAT
# 3      ABR
# 4      ABS
#       ...
# 409    VTB
# 410    VTO
# 411    VTP
# 412    YBM
# 413    YEG
# Name: symbol, Length: 414, dtype: object

# %%
stock.listing.symbols_by_group('HNX')
# Out:
# 0      AAV
# 1      ADC
# 2      ALT
# 3      AMC
# 4      AME
#       ...
# 306    VTV
# 307    VTZ
# 308    WCS
# 309    WSS
# 310    X20
# Name: symbol, Length: 311, dtype: object

# %%
df = stock.quote.history(symbol='VNM', start='2015-01-01', end='2024-09-18', interval='1D')

# %%
df
# Out:
#            time   open   high    low  close   volume
# 0    2015-01-05  20.48  20.48  20.31  20.44   320790
# 1    2015-01-06  20.35  20.53  20.31  20.53   462360
# 2    2015-01-07  20.53  20.61  20.40  20.48   319600
# 3    2015-01-08  20.48  20.78  20.48  20.61   788420
# 4    2015-01-09  20.61  20.87  20.53  20.53   969330
# ...         ...    ...    ...    ...    ...      ...
# 2421 2024-09-13  42.90  42.95  42.50  42.90  1526300
# 2422 2024-09-16  42.70  43.60  42.05  42.05  2005200
# 2423 2024-09-17  42.05  43.20  42.05  42.90  2237700
# 2424 2024-09-18  42.90  43.30  42.65  42.65  2746900
# 2425 2024-09-19  42.80  43.20  42.70  43.00  1368900
#
# [2426 rows x 6 columns]

# %%
df.to_csv('VNM.csv')
